# %% [markdown]
# ### 研究紹介の可視化等

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
x=np.linspace(0,100,101)
y=np.zeros(101)
y[10:30]=np.random.exponential(size=20)+10
y[30:60]=np.random.normal(loc=10,scale=1, size=30)
y[60:90]=np.random.binomial(n=3,p=0.5,size=30)+10

# %%
plt.figure(figsize=(10,3))
plt.plot(x[0:10],y[0:10],c='black')
plt.plot(x[90:],y[90:],c='black')
plt.plot(x[9:31],y[9:31])
plt.plot(x[30:61],y[30:61])
plt.plot(x[60:91],y[60:91])

# %% [markdown]
# ### データの紹介

# %% [markdown]
# #### データフレームの制作

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['A','B','C'])
df
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
y=np.zeros(120)
y[1:25]=np.random.exponential(size=24)+10
y[25:50]=np.random.normal(loc=10,scale=1, size=25)
y[50:80]=np.random.binomial(n=3,p=0.5,size=30)+10
df['A']=y
y[1:25]=np.random.exponential(size=24)+5
y[25:50]=np.random.normal(loc=6,scale=5, size=25)
y[50:80]=np.random.binomial(n=3,p=0.5,size=30)+5
df['B']=y
y[1:25]=np.random.exponential(size=24)-10
y[25:50]=np.random.normal(loc=-10,scale=1, size=25)
y[50:80]=np.random.binomial(n=3,p=0.5,size=30)-10
df['C']=y

# %%
df.plot(subplots=True,figsize=(8,4),rot=0)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1646c320>,
# ...
#       dtype=object)

# %%
y=np.zeros(120)
y[1:30]=np.random.exponential(size=29)+10
y[30:60]=np.random.normal(loc=10,scale=1, size=30)
y[60:110]=np.random.binomial(n=3,p=0.5,size=50)+10
df['A']=y
y[1:30]=np.random.exponential(size=29)+5
y[30:60]=np.random.normal(loc=5,scale=3, size=30)
y[60:110]=np.random.binomial(n=3,p=0.5,size=50)+5
df['B']=y
y[1:30]=np.random.exponential(size=29)-10
y[30:60]=np.random.normal(loc=-10,scale=1, size=30)
y[60:110]=np.random.binomial(n=3,p=0.5,size=50)-10
df['C']=y

# %%
df.plot(subplots=True,figsize=(8,4),rot=0)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a15f06c18>,
# ...
#       dtype=object)

# %%
df
# Out:
#              A         B          C
# 0     0.000000  0.000000   0.000000
# 1    10.081555  6.371491  -9.336037
# 2    10.163476  5.267866  -8.797017
# 3    12.247205  5.099457  -9.811760
# 4    10.649279  6.409903  -8.215210
# 5    11.709100  5.657979  -9.559986
# 6    10.056479  5.194710  -8.124458
# 7    13.031030  5.284905  -7.953766
# 8    11.937154  5.087600  -9.514255
# 9    10.464006  5.806309  -9.176683
# 10   10.076388  5.111191  -8.664383
# 11   10.318686  8.058106  -9.173395
# 12   10.060119  6.470134  -7.152463
# 13   11.775990  5.553027  -9.563219
# 14   10.116038  8.325081  -7.208455
# 15   10.650219  7.491991  -7.096222
# 16   10.546118  8.268216  -9.099730
# 17   10.990327  5.554425  -8.586086
# 18   10.809228  5.080111  -8.345787
# 19   10.065964  6.852950  -9.729848
# 20   12.034568  6.354094  -7.294661
# 21   10.249220  5.560127  -8.385074
# 22   11.761091  8.131106  -7.897214
# 23   11.281349  5.388962  -9.361955
# 24   10.349149  6.539578  -9.696769
# ...
