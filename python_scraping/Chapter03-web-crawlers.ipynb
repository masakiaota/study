# %% [markdown]
# ## wikiからリンクを取得する

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
#bsオブジェクトを作成してhref属性のものだけ抜き出す
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
#無駄なものも多く存在することに気づく
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com/
# #cite_note-1
# #cite_note-actor-2
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-3
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-4
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-5
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Personal_life
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Awards_and_nominations
# #Honors
# #Accolades
# #Filmography
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-2
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-6
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-7
# /wiki/Glory_Van_Scott
# #cite_note-walk-5
# #cite_note-bacon-6
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-8
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-6
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-9
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-10
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-11
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-12
# /wiki/Footloose_(1984_film)
# #cite_note-bio-10
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-13
# #cite_note-bacon-6
# #cite_note-14
# #cite_note-15
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-10
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-16
# /wiki/Tremors_(film)
# #cite_note-17
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-10
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-10
# /wiki/The_New_York_Times
# #cite_note-nyt94-18
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-19
# /wiki/A_Few_Good_Men_(film)
# #cite_note-20
# /wiki/Michael_Greif
# #cite_note-bio-10
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-10
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-10
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-21
# /wiki/Sleepers_(film)
# #cite_note-22
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-10
# /wiki/Losing_Chase
# #cite_note-austin-23
# /wiki/Digging_to_China
# #cite_note-bio-10
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-10
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-24
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-25
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-26
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-27
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# #cite_note-28
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-29
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# #cite_note-30
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-31
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-32
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-33
# #cite_note-34
# /wiki/The_Following
# #cite_note-35
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-36
# /wiki/Huffington_Post
# #cite_note-37
# /wiki/Tremors_(film)
# /wiki/Wikipedia:Citation_needed
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# #cite_note-38
# #cite_note-39
# /wiki/Egg_as_food
# #cite_note-40
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-8
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-41
# /wiki/Tracy_Pollan
# #cite_note-42
# #cite_note-43
# #cite_note-44
# /wiki/The_Times
# #cite_note-45
# #cite_note-46
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernard_Madoff
# #cite_note-financialpost-47
# #cite_note-48
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-49
# #cite_note-50
# #cite_note-51
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# #cite_note-52
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# #cite_note-53
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-54
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# #cite_note-55
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources
# //www.google.com/search?as_eq=wikipedia&q=%22Kevin+Bacon%22
# //www.google.com/search?tbm=nws&q=%22Kevin+Bacon%22+-wikipedia
# //www.google.com/search?&q=%22Kevin+Bacon%22+site:news.google.com/newspapers&source=newspapers
# //www.google.com/search?tbs=bks:1&q=%22Kevin+Bacon%22+-wikipedia
# //scholar.google.com/scholar?q=%22Kevin+Bacon%22
# https://www.jstor.org/action/doBasicSearch?Query=%22Kevin+Bacon%22&acc=on&wc=on
# /wiki/Help:Maintenance_template_removal
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-56
# /wiki/Denver_Film_Festival
# #cite_note-57
# /wiki/Phoenix_Film_Festival
# #cite_note-58
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-59
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-60
# /wiki/Seattle_International_Film_Festival
# #cite_note-61
# #cite_note-62
# /wiki/Apollo_13_(film)
# #cite_note-63
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-64
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-65
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Gold_Derby_Awards
# /wiki/Gold_Derby_Awards
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-4
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_5-0
# #cite_ref-walk_5-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_6-0
# #cite_ref-bacon_6-1
# #cite_ref-bacon_6-2
# #cite_ref-bacon_6-3
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-7
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_8-0
# #cite_ref-cosmo91_8-1
# #cite_ref-9
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_10-0
# #cite_ref-bio_10-1
# #cite_ref-bio_10-2
# #cite_ref-bio_10-3
# #cite_ref-bio_10-4
# #cite_ref-bio_10-5
# #cite_ref-bio_10-6
# #cite_ref-bio_10-7
# #cite_ref-bio_10-8
# #cite_ref-bio_10-9
# #cite_ref-bio_10-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_11-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-12
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_13-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-14
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-15
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-16
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-17
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_18-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-19
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-20
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-21
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-22
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_23-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-24
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-25
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-26
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-27
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-28
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-29
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-30
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-31
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_32-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_33-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-34
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-35
# http://www.fox.com/the-following/
# #cite_ref-36
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-37
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-38
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-39
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-40
# http://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-41
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-42
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-43
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-44
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-45
# #cite_ref-46
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_47-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-48
# #cite_ref-49
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-50
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-51
# http://www.drawtheline.org/sign-now/
# #cite_ref-52
# http://www.sixdegrees.org/
# #cite_ref-53
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-54
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-55
# http://baconbros.com/
# #cite_ref-56
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-57
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-58
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-59
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-60
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-61
# https://www.imdb.com/event/ev0000600/2015/1/
# #cite_ref-62
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-63
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-64
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-65
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /w/index.php?title=Template_talk:Kevin_Bacon&action=edit&redlink=1
# //en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kevin_Bacon_filmography
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# //en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Template:GoldenGlobeBestActorTVMiniseriesFilm
# /wiki/Template_talk:GoldenGlobeBestActorTVMiniseriesFilm
# //en.wikipedia.org/w/index.php?title=Template:GoldenGlobeBestActorTVMiniseriesFilm&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# //en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# //en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165
# /wiki/Bibsys
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# /wiki/Biblioth%C3%A8que_nationale_de_France
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# http://data.bnf.fr/ark:/12148/cb139817766
# /wiki/Integrated_Authority_File
# https://d-nb.info/gnd/124109659
# /wiki/International_Standard_Name_Identifier
# http://isni.org/isni/0000000121291300
# /wiki/Library_of_Congress_Control_Number
# https://id.loc.gov/authorities/names/n88034930
# /wiki/National_Library_of_Latvia
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# /wiki/MusicBrainz
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/National_Library_of_the_Czech_Republic
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# /wiki/National_Library_of_Australia
# https://nla.gov.au/anbd.aut-an36021861
# /wiki/SNAC
# http://socialarchive.iath.virginia.edu/ark:/99166/w6w67gw2
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# https://www.idref.fr/084292652
# /wiki/Virtual_International_Authority_File
# https://viaf.org/viaf/39570812
# /wiki/WorldCat_Identities
# https://www.worldcat.org/identities/containsVIAFID/39570812
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=892620852
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_January_2016
# /wiki/Category:BLP_articles_lacking_sources_from_October_2017
# /wiki/Category:All_BLP_articles_lacking_sources
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Wikipedia_articles_with_BIBSYS_identifiers
# /wiki/Category:Wikipedia_articles_with_BNE_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_LNB_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_NLA_identifiers
# /wiki/Category:Wikipedia_articles_with_SNAC-ID_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_WorldCat-VIAF_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=892620852
# /w/index.php?title=Kevin_Bacon&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=892620852
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=Kevin+Bacon
# /w/index.php?title=Special:ElectronPdf&page=Kevin+Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/

# %% [markdown]
# ## Retrieving Articles Only
# 上記を工夫して記事のリンクだけ抜き出すことに挑戦する。
#
# **リンクの共通点**
# 1. divの中にあり、idがbodyContentに設定っされている
# 2. URLの中に:がない
# 3. URLは/wiki/から始まる

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
# Kevin_Baconのページのbsオブジェクトを作る。

for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    # wikiのリンクを探す。
    if 'href' in link.attrs:
        print(link.attrs['href'])
        #リンクの内容を表示
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(film)
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# /wiki/Egg_as_food
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernard_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Gold_Derby_Awards
# /wiki/Gold_Derby_Awards
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Lortel_Archives
# /wiki/AllMovie
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kevin_Bacon_filmography
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Bibsys
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Integrated_Authority_File
# /wiki/International_Standard_Name_Identifier
# /wiki/Library_of_Congress_Control_Number
# /wiki/National_Library_of_Latvia
# /wiki/MusicBrainz
# /wiki/National_Library_of_the_Czech_Republic
# /wiki/National_Library_of_Australia
# /wiki/SNAC
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Virtual_International_Authority_File
# /wiki/WorldCat_Identities

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    '''
    上記のwikiのリンクを取得するコードを関数化したもの
    '''
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

# ランダムにリンクを選んで、そのページの中の記事をまたランダムに選ぶことを繰り返す処理
links = getLinks('/wiki/Kevin_Bacon')
end_cnt=0
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
    end_cnt+=1
    if end_cnt>10:
        #終了用に自分で追加した
        break
# Out:
# /wiki/Michael_Greif
# /wiki/The_New_York_Times
# /wiki/Jim_Hoagland
# /wiki/Anthony_Shadid
# /wiki/Westview_Press
# /wiki/Textbook
# /wiki/Kirtsaeng_v._John_Wiley_%26_Sons,_Inc.
# /wiki/2d_Cir.
# /wiki/John_F._Keenan
# /wiki/Frederick_Scullin
# /wiki/Lewis_A._Kaplan

# %% [markdown]
# ## 3.2 サイト全体をクローリングする
# ## Recursively crawling an entire site
# サイト全体を知るために再帰的にクローリングする

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set() #ここですでに訪れたサイトの履歴を保持しておく
def getLinks(pageUrl):
    global pages
    #自分で追加した強制終了条件
    if len(pages)>5:
        return 0
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage) #訪れたページは格納しておく
                getLinks(newPage) #再帰処理で再びクローリング
                #深さ優先探索みたいなことを行っている
getLinks('') #トップページからはじめる
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:WPPP
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:WikiProject_Protected_areas
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Consensus
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Edit_requests
# /wiki/Wikipedia:ADMIN
# /wiki/Wikipedia:Administrator_intervention_against_vandalism
# /wiki/Wikipedia:Username_policy
# /wiki/Wikipedia:Usernames_for_administrator_attention
# /wiki/Wikipedia:Appealing_a_block
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:3RR
# /wiki/Wikipedia:Administrators%27_noticeboard/Edit_warring
# /wiki/Wikipedia:BLOCK
# /wiki/Wikipedia:Administrators%27_noticeboard/Incidents
# /wiki/Wikipedia:Enforcement
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia:Banning_policy
# /wiki/Wikipedia:Blocking_policy
# /wiki/Template:Enforcement_policy_list
# /wiki/Template_talk:Enforcement_policy_list
# /wiki/File:Full-protection-shackle.svg
# /wiki/File:Template-protection-shackle.svg
# /wiki/File:Semi-protection-shackle.svg
# /wiki/File:Create-protection-shackle.svg
# /wiki/File:Move-protection-shackle.svg
# /wiki/File:Upload-protection-shackle.svg
# /wiki/File:Pending-protection-shackle.svg
# /wiki/File:Extended-protection-shackle.svg
# /wiki/File:Office-protection-shackle.svg
# /wiki/File:Cascade-protection-shackle.svg
# /wiki/Wiki
# /wiki/Wikipedia:Logging_in
# /wiki/Wikipedia:Autoconfirmed
# /wiki/Template:Pp-protected
# /wiki/Tooltip
# /wiki/Wikipedia:User_access_levels#Autoconfirmed_users
# /wiki/Wikipedia:Deletion_policy
# /wiki/Salting_the_earth
# /wiki/Help:Moving_a_page
# /wiki/Help:Upload
# /wiki/Wikipedia:User_access_levels#Reviewer
# /wiki/Wikipedia:AN
# /wiki/Wikipedia:Talk_page
# /wiki/Wikipedia:Office_actions
# /wiki/Wikipedia:AC
# /wiki/Wikipedia:RFUP
# /wiki/Special:Log/protect
# /wiki/Wikipedia:User_access_levels#Unregistered_users
# /wiki/Wikipedia:User_access_levels#New_users
# /wiki/Wikipedia:User_access_levels#Confirmed_users
# /wiki/Wikipedia:User_access_levels#Extended_confirmed_users
# /wiki/Wikipedia:User_access_levels#Pending_changes_reviewer
# /wiki/Wikipedia:Protection_policy#Pending_changes_protection
# /wiki/Wikipedia:Reviewing_pending_changes
# /wiki/Wikipedia:BLP
# /wiki/Wikipedia:Protection_policy#Semi-protection
# /wiki/Wikipedia:Protection_policy#Extended_confirmed_protection
# /wiki/Wikipedia:Arbitration_Committee
# /wiki/Wikipedia:Protection_policy#Template_protection
# /wiki/Wikipedia:User_access_levels#Template_editor
# /wiki/Wikipedia:High-risk_templates
# /wiki/Wikipedia:Protection_policy#Full_protection
# /wiki/Template:Protection_table
# /wiki/Template_talk:Protection_table
# /wiki/Template:Edit_fully_protected
# /wiki/Wikipedia:Stable_version
# /wiki/Wikipedia:Edit_war
# /wiki/Wikipedia:UNINVOLVED
# /wiki/Wikipedia:Vandalism
# /wiki/Wikipedia:COPYVIO
# /wiki/Wikipedia:Libel
# /wiki/Wikipedia:STABLE
# /wiki/Wikipedia:INVOLVED
# /wiki/Wikipedia:Deletion_review
# /wiki/Wikipedia:Restore
# /wiki/Template:TempUndelete
# /wiki/Help:Page_history
# /wiki/File:Photo.jpg
# /wiki/File:Interface-protection-shackle.svg
# /wiki/MediaWiki
# /wiki/Help:MediaWiki_namespace
# /wiki/MediaWiki:Common.js
# /wiki/Wikipedia:IADMIN
# /wiki/User:Example/monobook.css
# /wiki/User:Example/cologneblue.js
# /wiki/User:Example/data.json
# /wiki/Main_Page
# /wiki/File:Wiki.png
# /wiki/Wikipedia:General_disclaimer
# /wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# /wiki/Wikipedia:Transclusion
# /wiki/Template:Tl
# /wiki/Template:Ambox
# /wiki/Denial-of-service_attack
# /wiki/Wikipedia:Template_editor
# /wiki/Wikipedia:TEMPLATE
# /wiki/Wikipedia:LUA
# /wiki/Wikipedia:FULL
# /wiki/Wikipedia:TPE
# /wiki/Template:Edit_template-protected
# /wiki/Wikipedia:Rough_guide_to_semi-protection
# /wiki/Wikipedia:VD
# /wiki/Wikipedia:PC
# /wiki/Template:Edit_semi-protected
# /wiki/Wikipedia:RFED
# /wiki/Wikipedia:Requests_for_permissions/Confirmed
# /wiki/Category:Wikipedia_content_policies
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Neutral_point_of_view
# /wiki/Wikipedia:Wikipedia_in_the_media
# /wiki/Wikipedia:EW
# /wiki/Wikipedia:VANDAL
# /wiki/IP_address#Dynamic_IP
# /wiki/Dynamic_IP
# /wiki/IP_address_spoofing
# /wiki/Wikipedia:Today%27s_featured_article
# /wiki/Wikipedia:Main_Page_featured_article_protection
# /wiki/Special:ProtectedTitles
# /wiki/Wikipedia:Protected_titles/Historical
# /wiki/MediaWiki:Titleblacklist
# /wiki/Substring
# /wiki/Regular_expression
# /wiki/Wikipedia:Drafts
# /wiki/Wikipedia:ACPERM
# /wiki/Wikipedia:Administrators%27_noticeboard
# /wiki/Wikipedia:FILE
# /wiki/Wikipedia:File_mover
# /wiki/Wikipedia:Pending_changes
# /wiki/Wikipedia:IP
# /wiki/Wikipedia:CV
# /wiki/Wikipedia:Rough_guide_to_extended_confirmed_protection
# /wiki/Wikipedia:User_access_levels#Extendedconfirmed
# /wiki/Wikipedia:SOCK
# /wiki/Wikipedia:WAR
# /wiki/Wikipedia:General_sanctions/India%E2%80%93Pakistan_conflict
# /wiki/Wikipedia:Administrators%27_noticeboard#Pages_recently_put_under_extended-confirmed_protection
# /wiki/Template:Edit_extended-protected
# /wiki/Wikipedia:Office_actions#Protection
# /wiki/Wikipedia:Wikimedia_Foundation
# /wiki/Wikipedia:OFFICELIST
# /wiki/Wikipedia:Cascading_style_sheets
# /wiki/Wikipedia:Main_Page/Tomorrow
# /wiki/Wikipedia:Main_Page/Commons_media_protection
# /wiki/Template:In_the_news
# /wiki/Wikipedia:Template_documentation
# /wiki/Wikipedia:Cascade-protected_items
# /wiki/Wikipedia_talk:Cascade-protected_items
# /wiki/German_Wikipedia
# /wiki/Template:Edit_protected
# /wiki/Template:Unblock
# /wiki/Wikipedia:UTRS
# /wiki/Wikipedia:Appealing_a_block#Routes_to_unblock
# /wiki/Wikipedia:Sockpuppetry
# /wiki/Special:AbuseFilter/803
# /wiki/Template:Unlocked_userpage
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:Deceased_Wikipedians/Guidelines
# /wiki/Template:Documentation
# /wiki/Template:Pp-template
# /wiki/Wikipedia:Editnotice
# /wiki/Template:TFA_title
# /wiki/Wikipedia:Page_mover
# /wiki/Wikipedia:About_the_Sandbox
# /wiki/Help:Wiki_markup
# /wiki/Wikipedia:Sandbox
# /wiki/Wikipedia:No_personal_attacks
# /wiki/Wikipedia:Civility
# /wiki/Wikipedia:Copyrights
# /wiki/Category:Protection_templates
# /wiki/Template:Pp
# /wiki/Template:Pp-move
# /wiki/Template:Pp-pc
# /wiki/Template:Pp-upload
# /wiki/Template:Pp-blp
# /wiki/Template:Pp-dispute
# /wiki/Template:Pp-move-dispute
# /wiki/Template:Pp-30-500
# /wiki/Template:Pp-main-page
# /wiki/Template:Pp-office
# /wiki/Template:Pp-reset
# /wiki/Template:Pp-office-dmca
# /wiki/Template:Pp-sock
# /wiki/Template:Pp-usertalk
# /wiki/Template:Pp-vandalism
# /wiki/Template:Pp-move-vandalism
# /wiki/Template:Permanently_protected
# /wiki/Template:Temporarily_protected
# /wiki/Template:Pp-semi-indef
# /wiki/Template:Pp-move-indef
# /wiki/Module:Protection_banner
# /wiki/Template:Redirect_category_shell
# /wiki/MediaWiki:Protectedpagetext
# /wiki/Special:ProtectedPages
# /wiki/Wikipedia:Edit_lock
# /wiki/Wikipedia:List_of_indefinitely_protected_pages
# /wiki/Wikipedia:Make_protection_requests_sparingly
# /wiki/Wikipedia:Protection_policy/Padlocks
# /wiki/Wikipedia:Requests_for_comment/Template_editor_user_right
# /wiki/Wikipedia:Requests_for_comment/Extended_confirmed_protection_policy_2
# /wiki/Special:PermanentLink/734196666
# /wiki/Wikipedia:Arbitration/Requests/Case/Palestine-Israel_articles_3#500/30
# /wiki/Special:PermanentLink/720421803#Arbitration_motions_regarding_extended_confirmed_protection
# /wiki/Wikipedia:Village_pump_(proposals)/Archive_129#New_usergroup_with_autopromotion_to_implement_arbitration_"30-500"_bans_as_a_page_protection
# /wiki/Special:PermanentLink/884689437#Proposal:_Extended-confirmed_protection_for_India-Pakistan_conflict
# /wiki/Special:Diff/740835205
# /wiki/Special:PermanentLink/762319924#Make_PC2_no_longer_available_to_admins
# /wiki/Wikipedia:Requests_for_comment/Protect_user_pages_by_default
# /wiki/Wikipedia_talk:Requests_for_comment/Protect_user_pages_by_default
# /wiki/Wikipedia_talk:Protection_policy/Archive_15#Own_userspace_pages_protection_policy
# /wiki/Template:Administrators%27_guide
# /wiki/Template_talk:Administrators%27_guide
# /wiki/Wikipedia:Administrators%27_guide
# /wiki/Wikipedia:Advice_for_new_administrators
# /wiki/Wikipedia:Administrators%27_guide/Blocking
# /wiki/Wikipedia:Administrators%27_guide/Cleaning_backlogs
# /wiki/Wikipedia:Administrators%27_guide/Dealing_with_disputes
# /wiki/Wikipedia:Administrators%27_guide/Dealing_with_spam
# /wiki/Wikipedia:Administrators%27_guide/Deleting
# /wiki/Wikipedia:Administrators%27_guide/Edit_filters
# /wiki/Wikipedia:Administrators%27_guide/Fixing_cut-and-paste_moves
# /wiki/Wikipedia:Administrators%27_guide/Granting_and_revoking_user_rights
# /wiki/Wikipedia:Administrators%27_guide/Protecting
# /wiki/Wikipedia:Administrators%27_reading_list
# /wiki/Wikipedia:Administrators%27_guide/Rollback
# /wiki/Wikipedia:Administrators%27_guide/Tools
# /wiki/Wikipedia:Administrators%27_guide/Viewing_deleted_pages
# /wiki/Wikipedia:Revision_deletion
# /wiki/Template:Wikipedia_policies_and_guidelines
# /wiki/Template_talk:Wikipedia_policies_and_guidelines
# /wiki/Wikipedia:Five_pillars
# /wiki/Wikipedia:What_Wikipedia_is_not
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:No_original_research
# /wiki/Wikipedia:Image_use_policy
# /wiki/Wikipedia:Article_titles
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:Autobiography
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:Identifying_reliable_sources_(medicine)
# /wiki/Wikipedia:Do_not_include_the_full_text_of_lengthy_primary_sources
# /wiki/Wikipedia:Plagiarism
# /wiki/Wikipedia:Do_not_create_hoaxes
# /wiki/Wikipedia:Fringe_theories
# /wiki/Wikipedia:Patent_nonsense
# /wiki/Wikipedia:External_links
# /wiki/Wikipedia:Portal/Guidelines
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:Harassment
# /wiki/Wikipedia:Ownership_of_content
# /wiki/Wikipedia:Dispute_resolution
# /wiki/Wikipedia:Sock_puppetry
# /wiki/Wikipedia:No_legal_threats
# /wiki/Wikipedia:Paid-contribution_disclosure
# /wiki/Wikipedia:Assume_good_faith
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Disruptive_editing
# /wiki/Wikipedia:Do_not_disrupt_Wikipedia_to_illustrate_a_point
# /wiki/Wikipedia:Etiquette
# /wiki/Wikipedia:Gaming_the_system
# /wiki/Wikipedia:Please_do_not_bite_the_newcomers
# /wiki/Wikipedia:Courtesy_vanishing
# /wiki/Wikipedia:Responding_to_threats_of_harm
# /wiki/Wikipedia:Proposed_deletion
# /wiki/Wikipedia:Proposed_deletion_of_biographies_of_living_people
# /wiki/Wikipedia:Proposed_deletion_(books)
# /wiki/Wikipedia:Criteria_for_speedy_deletion
# /wiki/Wikipedia:Attack_page
# /wiki/Wikipedia:Oversight
# /wiki/Wikipedia:Article_size
# /wiki/Wikipedia:Be_bold
# /wiki/Wikipedia:Disambiguation
# /wiki/Wikipedia:Hatnote
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Wikipedia:Signatures
# /wiki/Wikipedia:Broad-concept_article
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Manual_of_Style/Contents
# /wiki/Wikipedia:Manual_of_Style/Accessibility
# /wiki/Wikipedia:Make_technical_articles_understandable
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers
# /wiki/Wikipedia:Manual_of_Style/Images
# /wiki/Wikipedia:Manual_of_Style/Layout
# /wiki/Wikipedia:Manual_of_Style/Lead_section
# /wiki/Wikipedia:Manual_of_Style/Linking
# /wiki/Wikipedia:Manual_of_Style/Lists
# /wiki/Wikipedia:Categories,_lists,_and_navigation_templates
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:Template_namespace
# /wiki/Wikipedia:Project_namespace
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:Userboxes
# /wiki/Wikipedia:Subpages
# /wiki/Wikipedia:List_of_policies_and_guidelines
# /wiki/Wikipedia:List_of_policies
# /wiki/Wikipedia:List_of_guidelines
# /wiki/Wikipedia:Principles
# /wiki/Help:Category
# /wiki/Category:Wikipedia_policies
# /wiki/Category:Wikipedia_enforcement_policies
# /wiki/Category:Wikipedia_Administrators%27_guide
# /wiki/Category:Wikipedia_vandalism
# /wiki/Category:Wikipedia_page_protection
# /wiki/Category:Wikipedia_move-protected_project_pages
# /wiki/Category:Wikipedia_semi-protected_project_pages
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia_talk:Protection_policy
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Special:WhatLinksHere/Wikipedia:Protection_policy
# /wiki/Special:RecentChangesLinked/Wikipedia:Protection_policy
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /wiki/Wikipedia:Requesting_copyright_permission
# /wiki/Wikipedia:Requests_for_permissions/Administrator_instructions
# /wiki/Special:Preferences
# /wiki/Wikipedia:Requests_for_permissions/Archive
# /wiki/File:Gtk-go-down.svg
# /wiki/File:Fairytale_key_enter-2.png
# /wiki/Wikipedia:Account_creator
# /wiki/Wikipedia:Requests_for_permissions/Account_creator
# /wiki/Wikipedia:Request_an_account/Guide
# /wiki/Wikipedia:Autopatrolled
# /wiki/Wikipedia:Requests_for_permissions/Autopatrolled
# /wiki/Special:Log/patrol
# /wiki/Special:NewPages
# /wiki/Wikipedia:AutoWikiBrowser
# /wiki/Wikipedia:Requests_for_permissions/AutoWikiBrowser
# /wiki/Microsoft_Windows
# /wiki/Wikipedia:AutoWikiBrowser/CheckPage#Guide
# /wiki/Wikipedia:User_access_levels
# /wiki/Wikipedia:AutoWikiBrowser/CheckPage
# /wiki/Wikipedia:Requests_for_permissions/Extended_confirmed
# /wiki/Wikipedia:Sock_puppetry#Legitimate_uses
# /wiki/Wikipedia:Protection_policy#Arbitration_30.2F500_protection
# /wiki/Wikipedia:Event_coordinator
# /wiki/Wikipedia:Requests_for_permissions/Event_coordinator
# /wiki/Wikipedia:Requests_for_permissions/File_mover
# /wiki/Wikipedia:Mass_message_senders
# /wiki/Wikipedia:Requests_for_permissions/Mass_message_sender
# /wiki/Wikipedia:Mass_message_senders#Requesting_a_mailing
# /wiki/Wikipedia:Mass_message_senders#Guidance_for_use
# /wiki/Wikipedia:New_pages_patrol/Reviewers
# /wiki/Wikipedia:Requests_for_permissions/New_page_reviewer
# /wiki/Wikipedia:Page_Curation
# /wiki/Wikipedia:Requests_for_permissions/Page_mover
# /wiki/Wikipedia:Moving_a_page
# /wiki/Wikipedia:Redirect
# /wiki/Wikipedia:Requests_for_permissions/Pending_changes_reviewer
# /wiki/Wikipedia:Rollback
# /wiki/Wikipedia:Requests_for_permissions/Rollback
# /wiki/Help:Reverting#Undo
# /wiki/Wikipedia:Cleaning_up_vandalism
# /wiki/Help:Reverting#Rollback
# /wiki/Wikipedia:Requests_for_permissions/Template_editor
# /wiki/Wikipedia:Lua
# /wiki/Wikipedia:Bureaucrats
# /wiki/Wikipedia:Requests_for_adminship
# /wiki/Wikipedia:Requests_for_adminship#Current_nominations_for_bureaucratship
# /wiki/Wikipedia:Bots
# /wiki/Wikipedia:Bots/Requests_for_approval
# /wiki/Wikipedia:Edit_filter
# /wiki/Wikipedia:Edit_filter_helper
# /wiki/Wikipedia:Edit_filter_noticeboard
# /wiki/Wikipedia:Interface_administrators
# /wiki/Wikipedia:Bureaucrats%27_noticeboard
# /wiki/Wikipedia:IP_block_exemption
# /wiki/Wikipedia:Unblock_Ticket_Request_System
# /wiki/Wikipedia:Functionaries
# /wiki/Wikipedia:CheckUser
# /wiki/Wikipedia:Arbitration_Committee/CheckUser_and_Oversight#Appointments
# /wiki/User:MusikBot
# /wiki/User:MusikBot/PermClerk#Configuration
# /wiki/Template:Done
# /wiki/Template:Not_done
# /wiki/Template:Already_done
# /wiki/Wikipedia:Requests_for_permissions/Approved
# /wiki/Wikipedia:Requests_for_permissions/Denied
# /wiki/User:MusikBot/PermClerk#Archiving
# /wiki/Wikipedia:ACCOUNT
# /wiki/User:WilderAddict
# /wiki/User_talk:WilderAddict
# /wiki/Special:Contributions/WilderAddict
# /wiki/Special:DeletedContributions/WilderAddict
# /wiki/Special:CentralAuth/WilderAddict
# /wiki/Special:UserRights/WilderAddict
# /wiki/User:I_dream_of_horses
# /wiki/User_talk:I_dream_of_horses
# /wiki/Special:Contributions/I_dream_of_horses
# /wiki/User:Swarm
# /wiki/User_talk:Swarm
# /wiki/User:Shevonsilva
# /wiki/User_talk:Shevonsilva
# /wiki/Special:Contributions/Shevonsilva
# /wiki/Special:DeletedContributions/Shevonsilva
# /wiki/Special:CentralAuth/Shevonsilva
# /wiki/Special:UserRights/Shevonsilva
# /wiki/User_talk:MusikAnimal
# /wiki/Kampung_Tanjung_Kubong
# /wiki/User:Schwede66
# /wiki/User_talk:Schwede66
# /wiki/User:Imaginatorium
# /wiki/User_talk:Imaginatorium
# /wiki/Wikipedia:Tendentious_editing
# /wiki/User:Joe_Roe
# /wiki/User_talk:Joe_Roe
# /wiki/User:Stuartyeates
# /wiki/User_talk:Stuartyeates
# /wiki/Special:Contributions/Stuartyeates
# /wiki/Special:DeletedContributions/Stuartyeates
# /wiki/Special:CentralAuth/Stuartyeates
# /wiki/Wikipedia:Sockpuppet_investigations/Stuartyeates
# /wiki/Special:UserRights/Stuartyeates
# /wiki/User:Ajpolino
# /wiki/User_talk:Ajpolino
# /wiki/User:Beeblebrox
# /wiki/User_talk:Beeblebrox
# /wiki/User_talk:Stuartyeates/Archive_22#Melinda_S._Allen
# /wiki/User_talk:A202985
# /wiki/Special:Contributions/A202985
# /wiki/Special:DeletedContributions/A202985
# /wiki/Special:CentralAuth/A202985
# /wiki/Special:UserRights/A202985
# /wiki/Wikipedia:MAINSPACE
# /wiki/User:LittlePuppers
# /wiki/User_talk:LittlePuppers
# /wiki/Special:Contributions/LittlePuppers
# /wiki/Special:DeletedContributions/LittlePuppers
# /wiki/Special:CentralAuth/LittlePuppers
# /wiki/Special:UserRights/LittlePuppers
# /wiki/User:LittlerPuppers
# /wiki/User:Genericusername57
# /wiki/User_talk:Genericusername57
# /wiki/Special:Contributions/Genericusername57
# /wiki/Special:DeletedContributions/Genericusername57
# /wiki/Special:CentralAuth/Genericusername57
# /wiki/Special:UserRights/Genericusername57
# /wiki/User:John_M_Wolfson
# /wiki/User_talk:John_M_Wolfson
# /wiki/Special:Contributions/John_M_Wolfson
# /wiki/Special:DeletedContributions/John_M_Wolfson
# /wiki/Special:CentralAuth/John_M_Wolfson
# /wiki/Special:UserRights/John_M_Wolfson
# /wiki/Notepad%2B%2B
# /wiki/User:RexxS
# /wiki/User_talk:RexxS
# /wiki/User:Balon_Greyjoy
# /wiki/User_talk:Balon_Greyjoy
# /wiki/Special:Contributions/Balon_Greyjoy
# /wiki/Special:DeletedContributions/Balon_Greyjoy
# /wiki/Special:CentralAuth/Balon_Greyjoy
# /wiki/Special:UserRights/Balon_Greyjoy
# /wiki/Wikipedia:Editcountitis
# /wiki/User_talk:ARIMA_CHAUDHARY
# /wiki/Special:Contributions/ARIMA_CHAUDHARY
# /wiki/Special:DeletedContributions/ARIMA_CHAUDHARY
# /wiki/Special:CentralAuth/ARIMA_CHAUDHARY
# /wiki/Special:UserRights/ARIMA_CHAUDHARY
# /wiki/User:JJMC89
# /wiki/User_talk:JJMC89
# /wiki/Special:Contributions/JJMC89
# /wiki/User_talk:Dollar123456
# /wiki/Special:Contributions/Dollar123456
# /wiki/Special:DeletedContributions/Dollar123456
# /wiki/Special:CentralAuth/Dollar123456
# /wiki/Special:UserRights/Dollar123456
# /wiki/User_talk:Filmtvproducer19
# /wiki/Special:Contributions/Filmtvproducer19
# /wiki/Special:DeletedContributions/Filmtvproducer19
# /wiki/Special:CentralAuth/Filmtvproducer19
# /wiki/Special:UserRights/Filmtvproducer19
# /wiki/Wikipedia:Files_for_upload
# /wiki/User:Erinamukuta
# /wiki/User_talk:Erinamukuta
# /wiki/Special:Contributions/Erinamukuta
# /wiki/Special:DeletedContributions/Erinamukuta
# /wiki/Special:CentralAuth/Erinamukuta
# /wiki/Special:UserRights/Erinamukuta
# /wiki/User:Stwalkerster
# /wiki/User_talk:Stwalkerster
# /wiki/User:DannyS712
# /wiki/User_talk:DannyS712
# /wiki/Special:Contributions/2607:F220:411:2141:0:0:0:1D
# /wiki/Special:DeletedContributions/2607:F220:411:2141:0:0:0:1D
# /wiki/Special:CentralAuth/2607:F220:411:2141:0:0:0:1D
# /wiki/Special:UserRights/2607:F220:411:2141:0:0:0:1D
# /wiki/User:Librarianaimee
# /wiki/Special:Contributions/Librarianaimee
# /wiki/Special:DeletedContributions/Librarianaimee
# /wiki/Special:CentralAuth/Librarianaimee
# /wiki/Special:UserRights/Librarianaimee
# /wiki/User:Miscellanye
# /wiki/User_talk:Miscellanye
# /wiki/Special:Contributions/miscellanye
# /wiki/Special:DeletedContributions/miscellanye
# /wiki/Special:CentralAuth/miscellanye
# /wiki/Special:UserRights/miscellanye
# /wiki/User:Alillich
# /wiki/Special:Contributions/Alillich
# /wiki/Special:DeletedContributions/Alillich
# /wiki/Special:CentralAuth/Alillich
# /wiki/Special:UserRights/Alillich
# /wiki/User:Xaosflux
# /wiki/User_talk:Xaosflux
# /wiki/User:Rob3512
# /wiki/User_talk:Rob3512
# /wiki/Special:Contributions/Rob3512
# /wiki/Special:DeletedContributions/Rob3512
# /wiki/Special:CentralAuth/Rob3512
# /wiki/Special:UserRights/Rob3512
# /wiki/User_talk:DeltaQuad
# /wiki/User:DeltaQuad
# /wiki/User:JalenFolf
# /wiki/User_talk:JalenFolf
# /wiki/Special:Contributions/JalenFolf
# /wiki/Special:DeletedContributions/JalenFolf
# /wiki/Special:CentralAuth/JalenFolf
# /wiki/Special:UserRights/JalenFolf
# /wiki/User:Manupriy_Ahluwalia
# /wiki/User_talk:Manupriy_Ahluwalia
# /wiki/Special:Contributions/Manupriy_Ahluwalia
# /wiki/Special:DeletedContributions/Manupriy_Ahluwalia
# /wiki/Special:CentralAuth/Manupriy_Ahluwalia
# /wiki/Special:UserRights/Manupriy_Ahluwalia
# /wiki/User:Masumrezarock100
# /wiki/User_talk:Masumrezarock100
# /wiki/Special:Contributions/Masumrezarock100
# /wiki/Special:DeletedContributions/Masumrezarock100
# /wiki/Special:CentralAuth/Masumrezarock100
# /wiki/Special:UserRights/Masumrezarock100
# /wiki/Wikipedia:AFC/Redirects
# /wiki/Wikipedia:FFU
# /wiki/Wikipedia:NPA
# /wiki/Wikipedia:NOTVANDALISM
# /wiki/User:Ceethekreator
# /wiki/User_talk:Ceethekreator
# /wiki/Special:Contributions/Ceethekreator
# /wiki/Special:DeletedContributions/Ceethekreator
# /wiki/Special:CentralAuth/Ceethekreator
# /wiki/Special:UserRights/Ceethekreator
# /wiki/Wikipedia:EDITCOUNTIS
# /wiki/User:Natg_19
# /wiki/User_talk:Natg_19
# /wiki/Special:Contributions/Natg_19
# /wiki/Special:DeletedContributions/Natg_19
# /wiki/Special:CentralAuth/Natg_19
# /wiki/Special:UserRights/Natg_19
# /wiki/User:The_Living_love
# /wiki/User_talk:The_Living_love
# /wiki/Special:Contributions/The_Living_love
# /wiki/Special:DeletedContributions/The_Living_love
# /wiki/Special:CentralAuth/The_Living_love
# /wiki/Special:UserRights/The_Living_love
# /wiki/User:MrClog
# /wiki/User_talk:MrClog
# /wiki/Special:Contributions/MrClog
# /wiki/Special:DeletedContributions/MrClog
# /wiki/Special:CentralAuth/MrClog
# /wiki/Special:UserRights/MrClog
# /wiki/Special:Diff/889249228#User:MrClog
# /wiki/User:Scribbley
# /wiki/User_talk:Scribbley
# /wiki/Special:Contributions/Scribbley
# /wiki/Special:DeletedContributions/Scribbley
# /wiki/Special:CentralAuth/Scribbley
# /wiki/Special:UserRights/Scribbley
# /wiki/User:Huldra
# /wiki/User_talk:Huldra
# /wiki/Special:Contributions/Huldra
# /wiki/Special:DeletedContributions/Huldra
# /wiki/Special:CentralAuth/Huldra
# /wiki/Special:UserRights/Huldra
# /wiki/Wikipedia_talk:Arbitration/Requests#Some_issues_relating_to_the_IP_area
# /wiki/Wikipedia:Arbitration/Requests/Clarification_and_Amendment#Clarification_request:_Palestine-Israel_articles_3
# /wiki/Template:Requests_for_permissions
# /wiki/Template_talk:Requests_for_permissions
# /wiki/Special:Log/rights
# /wiki/Wikipedia:Requests_for_adminship#About_RfB
# /wiki/Wikipedia:Edit_filter_helper#Process_for_requesting
# /wiki/Wikipedia:Edit_filter#User_right
# /wiki/Template:Wikipedia_accounts
# /wiki/Template_talk:Wikipedia_accounts
# /wiki/User_(computing)#User_account
# /wiki/Governance
# /wiki/Wikipedia:Why_create_an_account%3F
# /wiki/Special:CreateAccount
# /wiki/Wikipedia:Request_an_account
# /wiki/Wikipedia:IPs_are_human_too
# /wiki/Wikipedia:IP_addresses_are_not_people
# /wiki/Wikipedia:IP_hopper
# /wiki/Wikipedia:New_account
# /wiki/Help:Logging_in
# /wiki/Help:Reset_password
# /wiki/Wikipedia:Changing_username
# /wiki/Wikipedia:Unified_login
# /wiki/Wikipedia:Sock_puppetry#Legit
# /wiki/Wikipedia:Password_strength_requirements
# /wiki/Wikipedia:User_account_security
# /wiki/Wikipedia:Personal_security_practices
# /wiki/Help:Two-factor_authentication
# /wiki/Wikipedia:Using_AWB_with_2FA
# /wiki/Template:Committed_identity
# /wiki/Wikipedia:On_privacy,_confidentiality_and_discretion
# /wiki/Wikipedia:Compromised_accounts
# /wiki/Wikipedia:FAQ/Blocks
# /wiki/Wikipedia:Administrators%27_guide/Blocking/Tools
# /wiki/Wikipedia:Autoblock
# /wiki/Wikipedia:Guide_to_appealing_blocks
# /wiki/Wikipedia:Blocking_IP_addresses
# /wiki/Wikipedia:Open_proxies
# /wiki/Wikipedia:Arbitration_Committee/Ban_appeals
# /wiki/Wikipedia:Sanctions
# /wiki/Wikipedia:Editing_restrictions
# /wiki/Wikipedia:General_sanctions
# /wiki/Wikipedia:Arbitration_Committee/Discretionary_sanctions
# /wiki/Wikipedia:Arbitration_enforcement_log
# /wiki/Wikipedia:Sanctions_(essay)
# /wiki/Wikipedia:Long-term_abuse
# /wiki/Wikipedia:Standard_offer
# /wiki/Wikipedia:Single-purpose_account
# /wiki/Wikipedia:Sleeper_account
# /wiki/Wikipedia:Vandalism-only_account
# /wiki/Wikipedia:Wikibreak
# /wiki/Wikipedia:WikiProject_User_scripts/Scripts/WikiBreak_Enforcer
# /wiki/Wikipedia:Retiring
# /wiki/Wikipedia:Clean_start
# /wiki/User:Worm_That_Turned/Quiet_return
# /wiki/Wikipedia:Education_noticeboard
# /wiki/Wikipedia:Bot_policy
# /wiki/Wikipedia:Global_rights_policy
# /wiki/Wikipedia:Volunteer_Response_Team
# /wiki/Wikipedia:Role_of_Jimmy_Wales#Founder_flag
# /wiki/Wikipedia:Committees
# /wiki/Wikipedia:Bot_Approvals_Group
# /wiki/Wikipedia:Sockpuppet_investigations/SPI/Clerks
# /wiki/Wikipedia:Administration
# /wiki/Wikipedia:FAQ/Administration
# /wiki/Wikipedia:Formal_organization
# /wiki/Wikipedia:Editorial_oversight_and_control
# /wiki/Wikipedia:Quality_control
# /wiki/Wikipedia:Board_of_Trustees
# /wiki/Wikipedia:Founder%27s_seat
# /wiki/Wikipedia:Meta
# /wiki/Wikipedia:WikiProject
# /wiki/Wikipedia:Elections
# /wiki/Wikipedia:List_of_petitions
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:Reforms
# /wiki/Category:Project_pages_with_short_description
# /wiki/Category:Wikipedia_fully_protected_pages
# /wiki/Category:Wikipedia_template-protected_pages_other_than_templates_and_modules
# /wiki/Wikipedia_talk:Requests_for_permissions
# /wiki/Special:WhatLinksHere/Wikipedia:Requests_for_permissions
# /wiki/Special:RecentChangesLinked/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Random_page_patrol
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Wikipedia:Request_directory
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Administrators%27_noticeboard/Requests_for_closure
# /wiki/Wikipedia:Bots/Noticeboard
# /wiki/Wikipedia:Interface_administrators%27_noticeboard
# /wiki/Wikipedia:Main_Page/Errors
# /wiki/Wikipedia:WikiProject_on_open_proxies
# /wiki/Wikipedia:OTRS_noticeboard
# /wiki/Wikipedia:Requests_for_oversight
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# /wiki/Wikipedia:Media_copyright_questions
# /wiki/Wikipedia:Copyright_problems
# /wiki/Wikipedia:Dispute_resolution_noticeboard
# /wiki/Wikipedia:External_links/Noticeboard
# /wiki/Wikipedia:Fringe_theories/Noticeboard
# /wiki/Wikipedia:Neutral_point_of_view/Noticeboard
# /wiki/Wikipedia:No_original_research/Noticeboard
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:WikiProject_Resource_Exchange/Resource_Request
# /wiki/Wikipedia_talk:WikiProject_Spam
# /wiki/MediaWiki_talk:Spam-blacklist
# /wiki/MediaWiki_talk:Spam-whitelist
# /wiki/Wikipedia:SVG_help
# /wiki/MediaWiki_talk:Titleblacklist
# /wiki/Wikipedia:Pages_needing_translation_into_English
# /wiki/Wikipedia:Requests_for_history_merge
# /wiki/Wikipedia:Proposed_mergers
# /wiki/Wikipedia:Proposed_article_splits
# /wiki/Wikipedia:Requested_moves
# /wiki/Wikipedia:Requests_for_page_importation
# /wiki/Wikipedia:Deletion_process
# /wiki/Wikipedia:Articles_for_deletion
# /wiki/Wikipedia:Redirects_for_discussion
# /wiki/Wikipedia:Categories_for_discussion
# /wiki/Wikipedia:Templates_for_discussion
# /wiki/Wikipedia:Files_for_discussion
# /wiki/Wikipedia:Miscellany_for_deletion
# /wiki/Wikipedia:Requests_for_undeletion
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:Contributor_copyright_investigations
# /wiki/Wikipedia:Sockpuppet_investigations
# /wiki/Wikipedia:Arbitration_Committee/Noticeboard
# /wiki/Wikipedia:Arbitration/Requests
# /wiki/Wikipedia:Arbitration/Requests/Enforcement
# /wiki/Wikipedia:Edit_filter/Requested
# /wiki/Wikipedia:Editor_assistance/Requests
# /wiki/Wikipedia:Help_desk
# /wiki/Wikipedia:Teahouse
# /wiki/Wikipedia:Reference_desk
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Help_desk
# /wiki/Wikipedia:Requests_for_comment/All
# /wiki/Wikipedia:Village_pump_(idea_lab)
# /wiki/Wikipedia:Village_pump_(policy)
# /wiki/Wikipedia:Village_pump_(proposals)
# /wiki/Wikipedia:Village_pump_(technical)
# /wiki/Wikipedia:Village_pump_(miscellaneous)
# /wiki/Wikipedia:WikiProject_Council/Proposals
# /wiki/Category:Wikipedia_noticeboards
# /wiki/Wikipedia:Protection_policy#Creation_protection
# /wiki/Wikipedia:Requests_for_page_protection/Rolling_archive
# /wiki/Wikipedia:Twinkle
# /wiki/Help:Cheatsheet#Section_headings
# /wiki/File:Feed-icon.svg
# /wiki/News_aggregator
# /wiki/Web_feed
# /wiki/Wikipedia:Requests_for_page_protection/Header
# /wiki/Wikipedia:Requests_for_page_protection/Administrator_instructions
# /wiki/Erogenous_zone
# /wiki/Talk:Erogenous_zone
# /wiki/Special:WhatLinksHere/Erogenous_zone
# /wiki/User:Fish_and_karate
# /wiki/User:Flyer22_Reborn
# /wiki/User_talk:Flyer22_Reborn
# /wiki/User:El_C
# /wiki/Nabi_Rubin
# /wiki/Talk:Nabi_Rubin
# /wiki/Special:WhatLinksHere/Nabi_Rubin
# /wiki/Wikipedia:30/500
# /wiki/Wikipedia:ARBPIA3#500/30
# /wiki/User_talk:Nableezy
# /wiki/User:Oshwah
# /wiki/User_talk:Oshwah
# /wiki/Special:Contributions/Oshwah
# /wiki/Kyle_Lowry
# /wiki/Talk:Kyle_Lowry
# /wiki/Special:WhatLinksHere/Kyle_Lowry
# /wiki/User:Dane
# /wiki/User_talk:Dane
# /wiki/User:Lectonar
# /wiki/User_talk:Lectonar
# /wiki/Friedensreich_Hundertwasser
# /wiki/Talk:Friedensreich_Hundertwasser
# /wiki/Special:WhatLinksHere/Friedensreich_Hundertwasser
# /wiki/User:Rsfinlayson
# /wiki/User_talk:Rsfinlayson
# /wiki/Esa_Lindell
# /wiki/Talk:Esa_Lindell
# /wiki/Special:WhatLinksHere/Esa_Lindell
# /wiki/User:HickoryOughtShirt%3F4
# /wiki/User_talk:HickoryOughtShirt%3F4
# /wiki/%C3%81nima_Estudios
# /wiki/Talk:%C3%81nima_Estudios
# /wiki/Special:WhatLinksHere/%C3%81nima_Estudios
# /wiki/User_talk:Animawiki29
# /wiki/Deadweight
# /wiki/Talk:Deadweight
# /wiki/Special:WhatLinksHere/Deadweight
# /wiki/User_talk:AuroraButterfly
# /wiki/Cesaro_(wrestler)
# /wiki/Talk:Cesaro_(wrestler)
# /wiki/Special:WhatLinksHere/Cesaro_(wrestler)
# /wiki/User:STATicVapor
# /wiki/User_talk:STATicVapor
# /wiki/NSE_co-location_scam
# /wiki/Talk:NSE_co-location_scam
# /wiki/Special:WhatLinksHere/NSE_co-location_scam
# /wiki/User:J%C3%A9sk%C3%A9_Couriano
# /wiki/User_talk:J%C3%A9sk%C3%A9_Couriano
# /wiki/Special:Contributions/J%C3%A9sk%C3%A9_Couriano
# /wiki/Lisa_Kleypas
# /wiki/Talk:Lisa_Kleypas
# /wiki/Special:WhatLinksHere/Lisa_Kleypas
# /wiki/Wikipedia:VAND
# /wiki/User:Matt294069
# /wiki/User_talk:Matt294069
# /wiki/Pouya_(rapper)
# /wiki/Talk:Pouya_(rapper)
# /wiki/Special:WhatLinksHere/Pouya_(rapper)
# /wiki/Wikipedia:Red_link
# /wiki/Template:Edit_fully-protected
# /wiki/Wikipedia:Suggestions_for_COI_compliance
# /wiki/Template:Request_edit
# /wiki/Example
# /wiki/Talk:Example
# /wiki/Special:WhatLinksHere/Example
# /wiki/Category:Wikipedia_requests
# /wiki/Category:Wikipedia_requests_related_to_admins
# /wiki/Category:Non-talk_pages_that_are_automatically_signed
# /wiki/Wikipedia_talk:Requests_for_page_protection
# /wiki/Special:WhatLinksHere/Wikipedia:Requests_for_page_protection
# /wiki/Special:RecentChangesLinked/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia_(disambiguation)
# /wiki/Lists_of_encyclopedias
# /wiki/File:Wikipedia-logo-v2.svg
# /wiki/File:Wikipedia_wordmark.svg
# /wiki/Wikipedia_logo
# /wiki/Glyph
# /wiki/Writing_system
# /wiki/File:Wikipedia_Main_Page.png
# /wiki/Online_encyclopedia
# /wiki/Wikimedia_Foundation
# /wiki/Jimmy_Wales
# /wiki/Larry_Sanger
# /wiki/Alexa_Internet
# /wiki/Registered_user
# /wiki/List_of_Wikipedias#Grand_total
# /wiki/Creative_Commons_licenses
# /wiki/GFDL
# /wiki/LAMP_(software_bundle)
# /wiki/OCLC
# /wiki/Help:IPA/English
# /wiki/File:En-uk-Wikipedia.ogg
# /wiki/File:En-us-Wikipedia.ogg
# /wiki/Help:Pronunciation_respelling_key
# /wiki/Free_content
# /wiki/Advertising
# /wiki/Open_collaboration
# /wiki/World_Wide_Web
# /wiki/501(c)(3)_organization
# /wiki/Portmanteau
# /wiki/Hawai%27ian_language
# /wiki/Special:Statistics
# /wiki/English_Wikipedia
# /wiki/Nature_(journal)
# /wiki/Hard_science
# /wiki/Encyclop%C3%A6dia_Britannica
# /wiki/Time_(magazine)
# /wiki/Criticism_of_Wikipedia
# /wiki/Systemic_bias
# /wiki/Spin_(propaganda)
# /wiki/Facebook
# /wiki/Fake_news
# /wiki/YouTube
# /wiki/History_of_Wikipedia
# /wiki/File:Jimmy_Wales_September_2015.jpg
# /wiki/File:L_Sanger.jpg
# /wiki/Nupedia
# /wiki/File:Nupedia_logo_and_wordmark.png
# /wiki/Bomis
# /wiki/Web_portal
# /wiki/Open_Content
# /wiki/GNU_Free_Documentation_License
# /wiki/Richard_Stallman
# /wiki/Paul_Kennedy_(host)
# /wiki/Canadian_Broadcasting_Corporation
# /wiki/Domain_name
# /wiki/Slashdot
# /wiki/Web_search_engine
# /wiki/Yongle_Encyclopedia
# /wiki/Commercial_advertising
# /wiki/List_of_Wikipedias
# /wiki/Spanish_Wikipedia
# /wiki/Fork_(software_development)
# /wiki/Enciclopedia_Libre_Universal_en_Espa%C3%B1ol
# /wiki/Palo_Alto_Research_Center
# /wiki/Rey_Juan_Carlos_University
# /wiki/Madrid
# /wiki/Spain
# /wiki/Technology_Review
# /wiki/The_Atlantic
# /wiki/New_York_(magazine)
# /wiki/File:History_Wikipedia_English_SOPA_2012_Blackout2.jpg
# /wiki/Stop_Online_Piracy_Act
# /wiki/File:Wikipedia_Edit_2014.webm
# /wiki/List_of_most_popular_websites
# /wiki/ComScore
# /wiki/The_New_York_Times
# /wiki/Apple_Inc.
# /wiki/Page_view
# /wiki/Unique_visitor
# /wiki/PROTECT_IP_Act
# /wiki/2012_Wikipedia_blackout
# /wiki/File:Wikipedia-2001.jpg
# /wiki/Stigmergy
# /wiki/The_Economic_Times
# /wiki/Knowledge_Graph
# /wiki/Clay_Shirky
# /wiki/File:History_Comparison_Example_(Vector).png
# /wiki/Procrastination
# /wiki/Help:Semi-protection
# /wiki/Wikipedia:ECP
# /wiki/Wikipedia:XCON
# /wiki/Administrators_(Wikipedia)
# /wiki/File:Wikipedia_editing_interface.png
# /wiki/Help:Recent_changes
# /wiki/Recent_changes
# /wiki/Transaction_cost
# /wiki/Vandalism_on_Wikipedia
# /wiki/File:John_Seigenthaler_Sr._speaking.jpg
# /wiki/John_Seigenthaler
# /wiki/Seigenthaler_incident
# /wiki/Seigenthaler_biography_incident
# /wiki/USA_Today
# /wiki/Freedom_Forum
# /wiki/First_Amendment_Center
# /wiki/Vanderbilt_University
# /wiki/File:Jimbo_at_Fosdem_cropped.jpg
# /wiki/60_Minutes
# /wiki/CBS
# /wiki/Fosdem
# /wiki/Copyright
# /wiki/Virginia
# /wiki/Notability_in_the_English_Wikipedia
# /wiki/Wikipedia:Identifying_reliable_sources
# /wiki/Anarchy
# /wiki/Democracy
# /wiki/Tragedy_of_the_commons
# /wiki/Flow_(psychology)
# /wiki/Wikipedia:Wikipedians
# /wiki/Wikipedia:Third_opinion
# /wiki/Wikipedia:RfC
# /wiki/Arbitration_Committee
# /wiki/Wikipedia:Probation
# /wiki/Wikipedia:BAN
# /wiki/Anti-social_behavior
# /wiki/Wikipedia_community
# /wiki/File:Wikimania_-_the_Wikimentary.webm
# /wiki/Wikimania#2005
# /wiki/Frankfurt_am_Main
# /wiki/Germany
# /wiki/File:Editing_Hoxne_Hoard_at_the_British_Museum.ogv
# /wiki/British_Museum
# /wiki/Hoxne_Hoard
# /wiki/Cult
# /wiki/Credential
# /wiki/Anti-elitism
# /wiki/Wikipedia:Barnstars
# /wiki/Aaron_Swartz
# /wiki/Special:ActiveUsers
# /wiki/Wikipedia:SIG
# /wiki/IP_addresses
# /wiki/Dartmouth_College
# /wiki/Business_Insider
# /wiki/Henry_Blodget
# /wiki/Yale
# /wiki/Brown_University
# /wiki/Andrew_Lih
# /wiki/Africa
# /wiki/Cebuano_Wikipedia
# /wiki/Swedish_Wikipedia
# /wiki/French_Wikipedia
# /wiki/Dutch_Wikipedia
# /wiki/Internet_bot
# /wiki/Lsjbot
# /wiki/Cebuano_language
# /wiki/Waray_Wikipedia
# /wiki/Russian_Wikipedia
# /wiki/Italian_Wikipedia
# /wiki/Waray-Waray_Wikipedia
# /wiki/Polish_Wikipedia
# /wiki/Vietnamese_Wikipedia
# /wiki/Japanese_Wikipedia
# /wiki/Chinese_Wikipedia
# /wiki/Portuguese_Wikipedia
# /wiki/Ukrainian_Wikipedia
# /wiki/Persian_Wikipedia
# /wiki/Catalan_Wikipedia
# /wiki/Arabic_Wikipedia
# /wiki/Subdomain
# /wiki/Serbian_Wikipedia
# /wiki/File:TurkishWikipedia_block_pageviews_february-may2017.png
# /wiki/Turkish_Wikipedia
# /wiki/Block_of_Wikipedia_in_Turkey
# /wiki/American_and_British_English_spelling_differences
# /wiki/Color
# /wiki/Fair_use
# /wiki/File:User_-_demography.svg
# /wiki/Interwiki_links
# /wiki/PLoS_ONE
# /wiki/North_America
# /wiki/Simple_English_Wikipedia
# /wiki/The_Economist
# /wiki/Academic_studies_about_Wikipedia
# /wiki/Criticism_of_Wikipedia#Excessive_regulation
# /wiki/Edwin_Black
# /wiki/The_Chronicle_of_Higher_Education
# /wiki/The_Journal_of_Academic_Librarianship
# /wiki/Wikipedia:Undue
# /wiki/Oliver_Kamm
# /wiki/Education_Next
# /wiki/Spin_(public_relations)
# /wiki/Plagiarism
# /wiki/Reliability_of_Wikipedia
# /wiki/Confidence_interval
# /wiki/Sample_size
# /wiki/Accountability
# /wiki/Tyler_Cowen
# /wiki/Reference_work
# /wiki/Utility
# /wiki/Deutsche_Welle
# /wiki/Troll_(Internet)
# /wiki/Spam_(electronic)
# /wiki/Conflict-of-interest_editing_on_Wikipedia
# /wiki/Katherine_Maher
# /wiki/Stephen_Colbert
# /wiki/The_Colbert_Report
# /wiki/Lecturer
# /wiki/Academia
# /wiki/Primary_source
# /wiki/Email
# /wiki/The_Harvard_Crimson
# /wiki/Harvard_University
# /wiki/Syllabus
# /wiki/American_Library_Association
# /wiki/Michael_Gorman_(librarian)
# /wiki/Google
# /wiki/Health_information_on_Wikipedia
# /wiki/Amin_Azzam
# /wiki/James_Heilman
# /wiki/Wikipedia:WikiProject_Medicine
# /wiki/Carnegie_Mellon_University
# /wiki/Roy_Rosenzweig
# /wiki/Abraham_Lincoln
# /wiki/American_Civil_War
# /wiki/James_M._McPherson
# /wiki/William_Clarke_Quantrill
# /wiki/Cancer
# /wiki/Thomas_Jefferson_University
# /wiki/Credibility
# /wiki/Completeness_(knowledge_bases)
# /wiki/Objectivity_(science)
# /wiki/Readability
# /wiki/Relevance
# /wiki/Writing_style
# /wiki/Timeliness
# /wiki/Criticism_of_Wikipedia#Systemic_bias_in_coverage
# /wiki/Terabyte
# /wiki/Deletionism_and_inclusionism_in_Wikipedia
# /wiki/Wikipedia:Wikipedia_is_not#Wikipedia_is_not_censored
# /wiki/Online_petition_on_Wikipedia_Muhammad_article
# /wiki/Muhammad
# /wiki/Censorship_of_Wikipedia
# /wiki/China
# /wiki/Pakistan
# /wiki/File:Wikipedia_content_by_subject.png
# /wiki/Wikipedia:Wikipedia_Loves_Libraries
# /wiki/New_York_Public_Library_for_the_Performing_Arts
# /wiki/University_of_Minnesota
# /wiki/Oxford_Internet_Institute
# /wiki/The_Guardian
# /wiki/List_of_pornographic_actresses_by_decade
# /wiki/Women_writer
# /wiki/Cape_Town
# /wiki/Bias_in_Wikipedia
# /wiki/Internet_culture
# /wiki/Taha_Yasseri
# /wiki/University_of_Oxford
# /wiki/Counterproductive_work_behavior
# /wiki/George_W._Bush
# /wiki/Anarchism
# /wiki/Oxford
# /wiki/Croatia
# /wiki/Scientology
# /wiki/9/11_conspiracy_theories
# /wiki/Washington_University
# /wiki/Internet_Watch_Foundation_and_Wikipedia
# /wiki/Reporting_of_child_pornography_images_on_Wikimedia_Commons
# /wiki/Wikipedia:Wikipedia_is_not_censored
# /wiki/Feces
# /wiki/Cadaver
# /wiki/Human_penis
# /wiki/Vulva
# /wiki/Nudity
# /wiki/Sexual_content
# /wiki/Masturbation
# /wiki/Ejaculation
# /wiki/Zoophilia
# /wiki/Hardcore_pornography
# /wiki/Child_nudity
# /wiki/Virgin_Killer
# /wiki/Music_of_Germany
# /wiki/Heavy_metal_music
# /wiki/Rock_band
# /wiki/Scorpions_(band)
# /wiki/Prepubescent
# /wiki/Internet_service_provider
# /wiki/Internet_Watch_Foundation
# /wiki/Wikimedia_Commons
# /wiki/United_States_obscenity_law
# /wiki/Pedophilia
# /wiki/Lolicon
# /wiki/Child_pornography_laws_in_the_United_States#Section_1466A
# /wiki/Obscenity#United_States_obscenity_law
# /wiki/Wikipediocracy
# /wiki/Privacy
# /wiki/Public_figure
# /wiki/Cyberspace
# /wiki/Real_life
# /wiki/Meatspace
# /wiki/Tron_(hacker)
# /wiki/Right_to_privacy
# /wiki/OTRS
# /wiki/Gender_bias_on_Wikipedia
# /wiki/Sexism
# /wiki/Harassment
# /wiki/Cunt
# /wiki/File:Katherine_Maher.jpg
# /wiki/Lila_Tretikov
# /wiki/Wiktionary
# /wiki/Wikibooks
# /wiki/Wikimedia_movement_affiliates
# /wiki/List_of_Wikimedia_chapters
# /wiki/Catalan_language
# /wiki/Free_software
# /wiki/Open_source_software
# /wiki/Wiki_software
# /wiki/PHP
# /wiki/MySQL
# /wiki/Macro_(computer_science)
# /wiki/Variable_(programming)
# /wiki/Transclusion
# /wiki/Web_template
# /wiki/URL_redirection
# /wiki/GNU_General_Public_License
# /wiki/UseModWiki
# /wiki/Perl
# /wiki/CamelCase
# /wiki/PhpWiki
# /wiki/Magnus_Manske
# /wiki/Exponential_growth
# /wiki/Lee_Daniel_Crocker
# /wiki/Lucene
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# /wiki/Java_(programming_language)
# /wiki/VisualEditor
# /wiki/User:ClueBot_NG
# /wiki/IP_address
# /wiki/Malaysia_Airlines_Flight_17
# /wiki/Wikimedia_Foundation#Hardware
# /wiki/Squid_(software)
# /wiki/Linux_Virtual_Server
# /wiki/File:Wikimedia-servers-2010-12-28.svg
# /wiki/Cluster_(computing)
# /wiki/Linux
# /wiki/Ubuntu_(operating_system)
# /wiki/Amsterdam
# /wiki/Equinix
# /wiki/Ashburn,_Virginia
# /wiki/Industrial_organization
# /wiki/Wikipedia:Signpost
# /wiki/Wikimedia_project
# /wiki/Wikipedia:Wikipedia_Weekly
# /wiki/Wikipedia:BUGLE
# /wiki/Wikipedia:Milhist
# /wiki/Wikipedia:GOCE
# /wiki/Copyleft
# /wiki/GPL
# /wiki/Creative_Commons_license
# /wiki/Free_Software_Foundation
# /wiki/Wikipedia:Licensing_update
# /wiki/Copyright_law_of_Japan
# /wiki/Creative_Commons
# /wiki/Mirror_website
# /wiki/Reference.com
# /wiki/Answers.com
# /wiki/Wapedia
# /wiki/Hand-held_device
# /wiki/Android_(operating_system)
# /wiki/IOS
# /wiki/Wikipedia_App
# /wiki/Bing_(search_engine)
# /wiki/Powerset_(company)
# /wiki/DuckDuckGo
# /wiki/Optical_disc
# /wiki/Wikipedia_CD_Selection
# /wiki/SOS_Children%27s_Villages_UK
# /wiki/National_Curriculum_(UK)
# /wiki/Print_on_demand
# /wiki/Books_LLC
# /wiki/Mauritius
# /wiki/VDM_Publishing
# /wiki/DBpedia
# /wiki/Wikidata
# /wiki/Semantic_Web
# /wiki/Resource_Description_Framework
# /wiki/Web_crawler
# /wiki/Wikipedia:Database_download
# /wiki/Wikipedia:REFDESK
# /wiki/Journal_of_Documentation
# /wiki/Library_reference_desk
# /wiki/Help:Mobile_access
# /wiki/File:En_Wikipedia_front_page_on_Firefox_49,_Android_4.2.2.png
# /wiki/Web_browser
# /wiki/Internet_access
# /wiki/Mobile_web
# /wiki/Bloomberg_Businessweek
# /wiki/Sue_Gardner
# /wiki/Wireless_Application_Protocol
# /wiki/IPhone
# /wiki/WebOS
# /wiki/Metadata
# /wiki/Wikipedia:Metadata
# /wiki/Geoinformation
# /wiki/Wikipedia_Zero
# /wiki/Andrew_Brown_(writer)
# /wiki/Smart_phone
# /wiki/MIT_Technology_Review
# /wiki/Wikipedian
# /wiki/Status_quo
# /wiki/Noam_Cohen
# /wiki/Logistic_function
# /wiki/Pew_Research_Center
# /wiki/Wikipedia_in_culture
# /wiki/File:Wikipedia_Monument_in_S%C5%82ubice_-_detail.JPG
# /wiki/Wikipedia_Monument
# /wiki/S%C5%82ubice
# /wiki/Parliament_of_Canada
# /wiki/Same-sex_marriage
# /wiki/Civil_Marriage_Act
# /wiki/World_Intellectual_Property_Organization
# /wiki/United_States_Intelligence_Community
# /wiki/RNA_Biology
# /wiki/Rfam
# /wiki/Reddit
# /wiki/MySpace
# /wiki/BBC_Radio_4
# /wiki/Italy
# /wiki/Franco_Grillini
# /wiki/Freedom_of_panorama
# /wiki/File:Wikipedia,_an_introduction_-_Erasmus_Prize_2015.webm
# /wiki/Erasmus_Prize
# /wiki/File:Quadriga-verleihung-rr-02.jpg
# /wiki/Quadriga_(award)
# /wiki/The_Washington_Post
# /wiki/United_States_presidential_election,_2008
# /wiki/Reuters
# /wiki/Peter_Stone_(professor)
# /wiki/Stanford
# /wiki/One_Hundred_Year_Study_on_Artificial_Intelligence
# /wiki/Wired_(magazine)
# /wiki/Hossein_Derakhshan
# /wiki/Openness
# /wiki/Decentralization#Centralization_and_redecentralization_of_the_Internet
# /wiki/Social_media
# /wiki/Social_networking_service
# /wiki/Age_of_Enlightenment
# /wiki/Rationality
# /wiki/Typographic
# /wiki/Sapere_aude
# /wiki/Literal_translation
# /wiki/File:Wikipedia_team_visiting_to_Parliament_of_Oviedo_Spain_2015.JPG
# /wiki/File:Spanish_Wikipedians_meetup.jpg
# /wiki/Prix_Ars_Electronica
# /wiki/Austria
# /wiki/Webby_Award
# /wiki/Boris_Tadi%C4%87
# /wiki/Eckart_H%C3%B6fling
# /wiki/Peter_Gabriel
# /wiki/David_Weinberger
# /wiki/Princess_of_Asturias_Award
# /wiki/Asturian_language
# /wiki/Asturian_Wikipedia
# /wiki/Category:Parodies_of_Wikipedia
# /wiki/Wikiality
# /wiki/The_Onion
# /wiki/The_Office_(U.S._TV_series)
# /wiki/Michael_Scott_(The_Office)
# /wiki/Negotiation
# /wiki/My_Number_One_Doctor
# /wiki/Scrubs_(TV_series)
# /wiki/Perry_Cox
# /wiki/Raw_food_diet
# /wiki/Bone_cancer
# /wiki/List_of_Battlestar_Galactica_(2004_TV_series)_episodes
# /wiki/CollegeHumor
# /wiki/Dilbert
# /wiki/Bigipedia
# /wiki/Tosh.0
# /wiki/The_New_Yorker
# /wiki/Website
# /wiki/Chelsea_Manning
# /wiki/John_Julius_Norwich
# /wiki/The_Times
# /wiki/Wikimedia_projects
# /wiki/Wikiquote
# /wiki/Wikinews
# /wiki/Wikiversity
# /wiki/Wikispecies
# /wiki/Wikivoyage
# /wiki/File:WikiMedia_DC_2013_Annual_Meeting_08.JPG
# /wiki/Nicholas_G._Carr
# /wiki/Web_2.0
# /wiki/User-generated_content
# /wiki/Chris_Anderson_(writer)
# /wiki/Wisdom_of_crowds
# /wiki/Scientific_journal
# /wiki/Peer_review
# /wiki/Kathryn_Hughes
# /wiki/Text_corpus
# /wiki/Computational_linguistics
# /wiki/Information_retrieval
# /wiki/Natural_language_processing
# /wiki/Entity_linking
# /wiki/Word_sense_disambiguation
# /wiki/University_of_Franche-Comt%C3%A9
# /wiki/Besan%C3%A7on
# /wiki/Paul_Sabatier_University
# /wiki/Toulouse
# /wiki/PageRank
# /wiki/Massachusetts_Institute_of_Technology
# /wiki/Machine_learning
# /wiki/Artificial_intelligence
# /wiki/Data_quality
# /wiki/BBC_Domesday_Project
# /wiki/BBC_Micro
# /wiki/Everything2
# /wiki/GNE_(encyclopedia)
# /wiki/H2g2
# /wiki/Douglas_Adams
# /wiki/Knowledge_base
# /wiki/Susning.nu
# /wiki/Hudong
# /wiki/Baidu_Baike
# /wiki/Conservapedia
# /wiki/Encyclopedia_of_Life
# /wiki/Scholarpedia
# /wiki/Citizendium
# /wiki/File:Crystal_Clear_app_linneighborhood.svg
# /wiki/Portal:Internet
# /wiki/Democratization_of_knowledge
# /wiki/Interpedia
# /wiki/Internet
# /wiki/List_of_online_encyclopedias
# /wiki/List_of_Wikipedia_controversies
# /wiki/Network_effect
# /wiki/Outline_of_Wikipedia
# /wiki/Tree_structure
# /wiki/Portal:Contents/Outlines
# /wiki/Print_Wikipedia
# /wiki/QRpedia
# /wiki/Wikipedia_Review
# /wiki/Protected_page
# /wiki/UTC
# /wiki/Wikipedia:Suppression
# /wiki/U-T_San_Diego
# /wiki/Cf.
# /wiki/Wayback_Machine
# /wiki/Hitwise
# /wiki/Salt_Lake_City_Weekly
# /wiki/The_San_Diego_Union-Tribune
# /wiki/CBS_News
# /wiki/Jim_Giles_(reporter)
# /wiki/Bibcode
# /wiki/Digital_object_identifier
# /wiki/PubMed_Identifier
# /wiki/The_Register
# /wiki/History_News_Network
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/978-1-59420-153-0
# /wiki/Wikipedia:Modelling_Wikipedia_extended_growth
# /wiki/Open_access
# /wiki/Times_Internet_Limited
# /wiki/Jonathan_Zittrain
# /wiki/Special:BookSources/978-0-300-12487-3
# /wiki/Wikipedia:Tutorial/Registration
# /wiki/Wikipedia:Full_protection
# /wiki/Wikipedia:New_pages_patrol
# /wiki/First_Monday_(journal)
# /wiki/Special:BookSources/978-1-58113-702-6
# /wiki/Farrar,_Straus_%26_Giroux
# /wiki/Special:BookSources/978-0-374-29278-2
# /wiki/BusinessWeek
# /wiki/International_Herald_Tribune
# /wiki/Wikipedia:Ownership_of_articles
# /wiki/Wikipedia:Dispute_Resolution
# /wiki/NBC_News
# /wiki/Social_Science_Research_Network
# /wiki/Emory_Law_Journal
# /wiki/Fernanda_B._Vi%C3%A9gas
# /wiki/Martin_M._Wattenberg
# /wiki/IBM_Research
# /wiki/Kuro5hin.org
# /wiki/Special:BookSources/978-1-60558-007-4
# /wiki/CiteSeerX
# /wiki/Slate_(magazine)
# /wiki/Bloomberg_News
# /wiki/J%C3%A1nos_Kert%C3%A9sz
# /wiki/ArXiv
# /wiki/PubMed_Central
# /wiki/Bowling_Green_State_University
# /wiki/Category:CS1_maint:_Archived_copy_as_title
# /wiki/PC_World_(magazine)
# /wiki/Stacy_Schiff
# /wiki/Blog
# /wiki/University_of_California,_Berkeley
# /wiki/Berkman_Center_for_Internet_%26_Society
# /wiki/Harvard_Law_School
# /wiki/Robert_McHenry
# /wiki/TCS_Daily
# /wiki/The_Wall_Street_Journal
# /wiki/Brian_Bergstein
# /wiki/Special:BookSources/978-0-314-26408-4
# /wiki/Wikipedia:Link_rot
# /wiki/JSTOR
# /wiki/Special:BookSources/978-3-030-04849-5
# /wiki/Wikipedia:PAPER
# /wiki/Special:BookSources/978-1-4503-2263-8
# /wiki/Softpedia
# /wiki/The_Wikipedia_Revolution
# /wiki/Computerworld
# /wiki/Google_Scholar
# /wiki/Wikipedia:Wikipedia_CD_Selection
# /wiki/Frankfurter_Allgemeine_Zeitung
# /wiki/Wikimedia_Meta-Wiki
# /wiki/San_Antonio_Express-News
# /wiki/Cond%C3%A9_Nast
# /wiki/International_Standard_Serial_Number#Electronic_ISSN
# /wiki/International_Standard_Serial_Number
# /wiki/American_Broadcasting_Company
# /wiki/British_Comedy_Guide
# /wiki/Emily_Flake
# /wiki/Christopher_Caldwell_(journalist)
# /wiki/Financial_Times
# /wiki/MarketWatch
# /wiki/Times_Higher_Education
# /wiki/WebCite
# /wiki/Andrew_Orlowski
# /wiki/Special:BookSources/978-1-4214-1535-2
# /wiki/Loren_Terveen
# /wiki/John_Riedl
# /wiki/Special:BookSources/978-1-59593-845-9
# /wiki/Category:CS1_maint:_Uses_authors_parameter
# /wiki/Handle_System
# /wiki/Special:BookSources/978-9402813715
# /wiki/The_Journal_of_American_History
# /wiki/List_of_books_about_Wikipedia
# /wiki/Special:BookSources/978-1-59327-176-3
# /wiki/Wikipedia_%E2%80%93_The_Missing_Manual
# /wiki/Special:BookSources/978-0-596-51516-4
# /wiki/Special:BookSources/978-0-596-52174-5
# /wiki/Andrew_Dalby
# /wiki/Special:BookSources/978-0-9562052-0-9
# /wiki/Common_Knowledge%3F_An_Ethnography_of_Wikipedia
# /wiki/Stanford_University_Press
# /wiki/Special:BookSources/978-0-8047-8944-8
# /wiki/Andrew_Keen
# /wiki/The_Cult_of_the_Amateur
# /wiki/Special:BookSources/978-0-385-52080-5
# /wiki/The_Wikipedia_Revolution:_How_a_Bunch_of_Nobodies_Created_the_World%27s_Greatest_Encyclopedia
# /wiki/Special:BookSources/978-1-4013-0371-6
# /wiki/Special:BookSources/978-0-7546-7433-7
# /wiki/Sheizaf_Rafaeli
# /wiki/Cambridge_University_Press
# /wiki/Special:BookSources/978-0-262-01447-2
# /wiki/Special:BookSources/978-9-333-39061-3
# /wiki/Nicholson_Baker
# /wiki/The_New_York_Review_of_Books
# /wiki/L._Gordon_Crovitz
# /wiki/Virginia_Postrel
# /wiki/Pacific_Standard
# /wiki/Web_conferencing
# /wiki/Ideas_(radio_show)
# /wiki/CBC_Radio_One
# /wiki/Kat_Walsh
# /wiki/List_of_films_about_Wikipedia
# /wiki/Houston_Chronicle
# /wiki/New_Scientist
# /wiki/The_Phoenix_(newspaper)
# /wiki/Marshall_Poe
# /wiki/Media_in_New_York%27s_Capital_District
# /wiki/Vice_(magazine)
# /wiki/Cato_Institute
# /wiki/Wikipedia:Wikimedia_sister_projects
# /wiki/Curlie
# /wiki/Template:Wikipedia
# /wiki/Template_talk:Wikipedia
# /wiki/Ideological_bias_on_Wikipedia
# /wiki/Racial_bias_on_Wikipedia
# /wiki/Predictions_of_the_end_of_Wikipedia
# /wiki/Wikipedia_administrators
# /wiki/AfroCrowd
# /wiki/Citation_needed
# /wiki/Edit-a-thon
# /wiki/Ignore_all_rules
# /wiki/The_Signpost
# /wiki/Wikipedian_in_residence
# /wiki/Wikimania
# /wiki/WikiProject
# /wiki/Women_in_Red
# /wiki/List_of_Wikipedia_people
# /wiki/Florence_Devouard
# /wiki/Erik_M%C3%B6ller
# /wiki/Ira_Brad_Matetsky
# /wiki/Wikimedian_of_the_Year
# /wiki/United_States_Congressional_staff_edits_to_Wikipedia
# /wiki/Essjay_controversy
# /wiki/Wikipedia_Seigenthaler_biography_incident
# /wiki/Henryk_Batuta_hoax
# /wiki/Jar%27Edo_Wens_hoax
# /wiki/Church_of_Scientology_editing_on_Wikipedia
# /wiki/Italian_Wikipedia#2011_mass_blanking_protest
# /wiki/Protests_against_SOPA_and_PIPA#Wikimedia_community
# /wiki/Hillsborough_Wikipedia_posts
# /wiki/MyWikiBiz
# /wiki/Art%2BFeminism
# /wiki/1Lib1Ref
# /wiki/Princess_of_Asturias_Awards
# /wiki/Bibliography_of_Wikipedia
# /wiki/Listen_to_Wikipedia
# /wiki/Wiki-Watch
# /wiki/WikiScanner
# /wiki/List_of_Wikipedia_mobile_applications
# /wiki/WikiNodes
# /wiki/Wikiwand
# /wiki/Boundless_(company)
# /wiki/Deletionpedia
# /wiki/Kiwix
# /wiki/WikiReader
# /wiki/Science_information_on_Wikipedia
# /wiki/Everipedia
# /wiki/Veropedia
# /wiki/List_of_wikis
# /wiki/Wikimedia_movement
# /wiki/The_Iraq_War:_A_Historiography_of_Wikipedia_Changelogs
# /wiki/Magna_Carta_(An_Embroidery)
# /wiki/274301_Wikipedia
# /wiki/Portal:Wikipedia
# /wiki/Category:Wikipedia
# /wiki/Template:Wikis
# /wiki/Template_talk:Wikis
# /wiki/Personal_wiki
# /wiki/List_of_medical_wikis
# /wiki/Semantic_wiki
# /wiki/Wiki_hosting_service
# /wiki/List_of_wiki_software
# /wiki/Comparison_of_wiki_software
# /wiki/Comparison_of_wiki_hosting_services
# /wiki/History_of_wikis
# /wiki/Creole_(markup)
# /wiki/Template:Wikimedia_Foundation
# /wiki/Template_talk:Wikimedia_Foundation
# /wiki/Aaron_Halfaker
# /wiki/Dariusz_Jemielniak
# /wiki/Hampton_Catlin
# /wiki/Danese_Cooper
# /wiki/Bishakha_Datta
# /wiki/Oscar_van_Dillen
# /wiki/Arnnon_Geshuri
# /wiki/Mike_Godwin
# /wiki/Guy_Kawasaki
# /wiki/Luis_Villa
# /wiki/Patricio_Lorente
# /wiki/List_of_Wiktionaries
# /wiki/Wikisource
# /wiki/Litigation_involving_the_Wikimedia_Foundation
# /wiki/Wikimedia_Foundation_v._NSA
# /wiki/Knowledge_Engine_(Wikimedia_Foundation)
# /wiki/Template:Wikipedias
# /wiki/Template_talk:Wikipedias
# /wiki/Norwegian_Wikipedia
# /wiki/Indonesian_Wikipedia
# /wiki/Finnish_Wikipedia
# /wiki/Korean_Wikipedia
# /wiki/Serbo-Croatian_Wikipedia
# /wiki/Hungarian_Wikipedia
# /wiki/Czech_Wikipedia
# /wiki/Romanian_Wikipedia
# /wiki/Basque_Wikipedia
# /wiki/Malay_Wikipedia
# /wiki/Esperanto_Wikipedia
# /wiki/Armenian_Wikipedia
# /wiki/Bulgarian_Wikipedia
# /wiki/Danish_Wikipedia
# /wiki/Hebrew_Wikipedia
# /wiki/Slovak_Wikipedia
# /wiki/Southern_Min_Wikipedia
# /wiki/Kazakh_Wikipedia
# /wiki/Minangkabau_Wikipedia
# /wiki/List_of_Wikipedias#C
# /wiki/Croatian_Wikipedia
# /wiki/Lithuanian_Wikipedia
# /wiki/Estonian_Wikipedia
# /wiki/Belarusian_Wikipedia
# /wiki/Slovene_Wikipedia
# /wiki/Greek_Wikipedia
# /wiki/Galician_Wikipedia
# /wiki/Azerbaijani_Wikipedia
# /wiki/Urdu_Wikipedia
# /wiki/Southern_Azerbaijani_Wikipedia
# /wiki/Uzbek_Wikipedia
# /wiki/Thai_Wikipedia
# /wiki/Latin_Wikipedia
# /wiki/Hindi_Wikipedia
# /wiki/Georgian_Wikipedia
# /wiki/Volap%C3%BCk_Wikipedia
# /wiki/Tamil_Wikipedia
# /wiki/Welsh_Wikipedia
# /wiki/Macedonian_Wikipedia
# /wiki/List_of_Wikipedias#T
# /wiki/Latvian_Wikipedia
# /wiki/Malagasy_Wikipedia
# /wiki/Occitan_Wikipedia
# /wiki/Tagalog_Wikipedia
# /wiki/Tatar_Wikipedia
# /wiki/Kyrgyz_Wikipedia
# /wiki/Bosnian_Wikipedia
# /wiki/Albanian_Wikipedia
# /wiki/Nepal_Bhasa_Wikipedia
# /wiki/Afrikaans_Wikipedia
# /wiki/Cantonese_Wikipedia
# /wiki/Telugu_Wikipedia
# /wiki/Breton_Wikipedia
# /wiki/List_of_Wikipedias#P
# /wiki/Bengali_Wikipedia
# /wiki/Malayalam_Wikipedia
# /wiki/Javanese_Wikipedia
# /wiki/Luxembourgish_Wikipedia
# /wiki/List_of_Wikipedias#H
# /wiki/Scots_Wikipedia
# /wiki/Marathi_Wikipedia
# /wiki/Irish_Wikipedia
# /wiki/Punjabi_Wikipedia
# /wiki/Icelandic_Wikipedia
# /wiki/List_of_Wikipedias#B
# /wiki/Swahili_Wikipedia
# /wiki/Chuvash_Wikipedia
# /wiki/West_Frisian_Wikipedia
# /wiki/List_of_Wikipedias#S
# /wiki/Burmese_Wikipedia
# /wiki/List_of_Wikipedias#L
# /wiki/Aragonese_Wikipedia
# /wiki/Yoruba_Wikipedia
# /wiki/List_of_Wikipedias#N
# /wiki/List_of_Wikipedias#G
# /wiki/List_of_Wikipedias#I
# /wiki/Bavarian_Wikipedia
# /wiki/Sicilian_Wikipedia
# /wiki/Bishnupriya_Manipuri_Wikipedia
# /wiki/Alemannic_Wikipedia
# /wiki/Kurdish_(Kurmanji)_Wikipedia
# /wiki/Kannada_Wikipedia
# /wiki/Kurdish_(Sorani)_Wikipedia
# /wiki/List_of_Wikipedias#Q
# /wiki/Egyptian_Arabic_Wikipedia
# /wiki/Mongolian_Wikipedia
# /wiki/Megrelian_Wikipedia
# /wiki/Samogitian_Wikipedia
# /wiki/Scottish_Gaelic_Wikipedia
# /wiki/List_of_Wikipedias#W
# /wiki/Yiddish_Wikipedia
# /wiki/List_of_Wikipedias#A
# /wiki/Buginese_Wikipedia
# /wiki/Odia_Wikipedia
# /wiki/List_of_Wikipedias#M
# /wiki/List_of_Wikipedias#U
# /wiki/Faroese_Wikipedia
# /wiki/Maithili_Wikipedia
# /wiki/Mengrelian_Wikipedia
# /wiki/Sanskrit_Wikipedia
# /wiki/Ilocano_Wikipedia
# /wiki/Venetian_Wikipedia
# /wiki/Ossetian_Wikipedia
# /wiki/Hill_Mari_Wikipedia
# /wiki/List_of_Wikipedias#E
# /wiki/Sindhi_Wikipedia
# /wiki/Fiji_Hindi_Wikipedia
# /wiki/Pashto_Wikipedia
# /wiki/List_of_Wikipedias#Z
# /wiki/Classical_Chinese_Wikipedia
# /wiki/Silesian_Wikipedia
# /wiki/Northern_Sami_Wikipedia
# /wiki/Dutch_Low_Saxon_Wikipedia
# /wiki/Rusyn_Wikipedia
# /wiki/Crimean_Tatar_Wikipedia
# /wiki/Corsican_Wikipedia
# /wiki/V%C3%B5ro_Wikipedia
# /wiki/Abkhazian_Wikipedia
# /wiki/Assamese_Wikipedia
# /wiki/Uyghur_Wikipedia
# /wiki/Konkani_Wikipedia
# /wiki/Guarani_Wikipedia
# /wiki/Divehi_Wikipedia
# /wiki/Extremaduran_Wikipedia
# /wiki/Kabyle_Wikipedia
# /wiki/Ripuarian_Wikipedia
# /wiki/Pali_Wikipedia
# /wiki/Karakalpak_Wikipedia
# /wiki/Aramaic_Wikipedia
# /wiki/Tuvan_Wikipedia
# /wiki/Tok_Pisin_Wikipedia
# /wiki/Wolof_Wikipedia
# /wiki/Zulu_Wikipedia
# /wiki/Tulu_Wikipedia
# /wiki/Xhosa_Wikipedia
# /wiki/Bambara_Wikipedia
# /wiki/Santali_Wikipedia
# /wiki/Kashmiri_Wikipedia
# /wiki/Venda_Wikipedia
# /wiki/Help:Authority_control
# /wiki/Bibsys
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Integrated_Authority_File
# /wiki/International_Standard_Name_Identifier
# /wiki/Library_of_Congress_Control_Number
# /wiki/National_Library_of_the_Czech_Republic
# /wiki/National_and_University_Library_in_Zagreb
# /wiki/LIBRIS
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Virtual_International_Authority_File
# /wiki/WorldCat_Identities
# /wiki/Category:2001_establishments_in_the_United_States
# /wiki/Category:Advertising-free_websites
# /wiki/Category:American_websites
# /wiki/Category:Internet_properties_established_in_2001
# /wiki/Category:Social_information_processing
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Pages_containing_links_to_subscription-only_content
# /wiki/Category:CS1_German-language_sources_(de)
# /wiki/Category:All_articles_with_dead_external_links
# /wiki/Category:Articles_with_dead_external_links_from_December_2016
# /wiki/Category:Articles_with_permanently_dead_external_links
# /wiki/Category:Articles_containing_German-language_text
# /wiki/Category:Articles_with_dead_external_links_from_July_2015
# /wiki/Category:Articles_with_dead_external_links_from_April_2019
# /wiki/Category:CS1_Italian-language_sources_(it)
# /wiki/Category:CS1_Spanish-language_sources_(es)
# /wiki/Category:Webarchive_template_webcite_links
# /wiki/Category:Wikipedia_pages_semi-protected_against_vandalism
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Use_American_English_from_November_2015
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Use_mdy_dates_from_March_2019
# /wiki/Category:Pages_using_deprecated_image_syntax
# /wiki/Category:Articles_containing_potentially_dated_statements_from_February_2019
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Articles_with_hAudio_microformats
# /wiki/Category:Pages_including_recorded_pronunciations_(English)
# /wiki/Category:Articles_containing_potentially_dated_statements_from_April_2019
# /wiki/Category:Articles_containing_potentially_dated_statements_from_January_2019
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_March_2018
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2014
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_March_2017
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_November_2016
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_June_2017
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2008
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_October_2015
# /wiki/Category:Articles_containing_potentially_dated_statements_from_December_2010
# /wiki/Category:Articles_containing_potentially_dated_statements_from_December_2009
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2007
# /wiki/Category:Articles_containing_Latin-language_text
# /wiki/Category:Articles_with_Curlie_links
# /wiki/Category:Articles_containing_Spanish-language_text
# /wiki/Category:Wikipedia_articles_with_BIBSYS_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_NSK_identifiers
# /wiki/Category:Wikipedia_articles_with_SELIBR_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_WorldCat-VIAF_identifiers
# /wiki/Category:Articles_containing_video_clips
# /wiki/Category:Pages_using_the_Graph_extension
# /wiki/Talk:Wikipedia
# /wiki/Special:WhatLinksHere/Wikipedia
# /wiki/Special:RecentChangesLinked/Wikipedia
# /wiki/Encyclopedia
# /wiki/Wikipedia:Introduction
# /wiki/English_language
# /wiki/Portal:Arts
# /wiki/Portal:Biography
# /wiki/Portal:Geography
# /wiki/Portal:History
# /wiki/Portal:Mathematics
# /wiki/Portal:Science
# /wiki/Portal:Society
# /wiki/Portal:Technology
# /wiki/Portal:Contents/Portals
# /wiki/File:Pitta_sordida_-_Sri_Phang_Nga_(mirrored_square_crop).jpg
# /wiki/Pitta
# /wiki/Family_(biology)
# /wiki/Bird
# /wiki/Genus
# /wiki/Pitta_(genus)
# /wiki/Erythropitta
# /wiki/Hydrornis
# /wiki/Tyranni
# /wiki/Broadbill
# /wiki/Passerine
# /wiki/Tail
# /wiki/Beak
# /wiki/Plumage
# /wiki/Tropics
# /wiki/Temperate_climate
# /wiki/Shrubland
# /wiki/Mangrove_swamp
# /wiki/Earthworm
# /wiki/Snail
# /wiki/Insect
# /wiki/Deforestation
# /wiki/Wildlife_trade
# /wiki/Jeremy_Thorpe
# /wiki/Thomas_Crisp
# /wiki/Teresa_Sampsonia
# /wiki/Wikipedia:Today%27s_featured_article/April_2019
# /wiki/Wikipedia:Featured_articles
# /wiki/File:Lord_Downpatrick.jpg
# /wiki/Edward_Windsor,_Lord_Downpatrick
# /wiki/Elizabeth_II
# /wiki/Succession_to_the_British_throne
# /wiki/Act_of_Settlement_1701#Removal_from_the_succession_due_to_Catholicism
# /wiki/Pacific_baza
# /wiki/Lincolnshire_County_Council
# /wiki/David_Bowles_(chief_executive)
# /wiki/Jim_Speechley
# /wiki/Ian_Croft
# /wiki/Armed_Forces_March_Competition
# /wiki/Cornet
# /wiki/John_Philip_Sousa
# /wiki/Stella_Abidh
# /wiki/Indo-Trinidadian_and_Tobagonian
# /wiki/Western_Australia
# /wiki/2016_AFL_Youth_Girls_National_Championships
# /wiki/Rosl_Schwaiger
# /wiki/Die_Entf%C3%BChrung_aus_dem_Serail
# /wiki/Salzburg_Festival
# /wiki/Glyndebourne_Festival_Opera
# /wiki/Pok%C3%A9mon_Go_live_events
# /wiki/Yokohama
# /wiki/Wikipedia:Recent_additions
# /wiki/Wikipedia:Your_first_article
# /wiki/Template_talk:Did_you_know
# /wiki/File:Kenneth_2019-04-25_0745Z.jpg
# /wiki/Cyclone_Kenneth
# /wiki/Comoro_Islands
# /wiki/2019_Luzon_earthquake
# /wiki/Luzon
# /wiki/Volodymyr_Zelensky
# /wiki/2019_Ukrainian_presidential_election
# /wiki/2019_Sri_Lanka_Easter_bombings
# /wiki/Mueller_Report
# /wiki/Deaths_in_2019
# /wiki/Sylvia_Bretschneider
# /wiki/Richard_Lugar
# /wiki/Ellen_Schwiers
# /wiki/John_Havlicek
# /wiki/Martin_Kilson
# /wiki/Nils_John_Nilsson
# /wiki/Wikipedia:In_the_news/Candidates
# /wiki/April_30
# /wiki/Reunification_Day
# /wiki/File:Coxey_commonweal_army_brightwood_leaving.jpg
# /wiki/1557
# /wiki/Arauco_War
# /wiki/Francisco_de_Villagra
# /wiki/Battle_of_Mataquito
# /wiki/Mapuche
# /wiki/Toqui
# /wiki/Lautaro
# /wiki/1894
# /wiki/Coxey%27s_Army
# /wiki/Panic_of_1893
# /wiki/Demonstration_(political)
# /wiki/1945
# /wiki/World_War_II
# /wiki/Allies_of_World_War_II
# /wiki/Adolf_Hitler
# /wiki/Eva_Braun
# /wiki/Death_of_Adolf_Hitler
# /wiki/F%C3%BChrerbunker
# /wiki/1982
# /wiki/Ananda_Marga
# /wiki/Kolkata
# /wiki/Bijon_Setu_massacre
# /wiki/2009
# /wiki/2009_attack_on_the_Dutch_royal_family
# /wiki/Monarchy_of_the_Netherlands
# /wiki/Robert_Plot
# /wiki/Dadasaheb_Phalke
# /wiki/Meredith_L._Patterson
# /wiki/April_29
# /wiki/May_1
# /wiki/Wikipedia:Selected_anniversaries/April
# /wiki/List_of_historical_anniversaries
# /wiki/File:M81.jpg
# /wiki/Messier_81
# /wiki/Spiral_galaxy
# /wiki/Light_year
# /wiki/Ursa_Major
# /wiki/Milky_Way
# /wiki/Johann_Elert_Bode
# /wiki/Active_galactic_nucleus
# /wiki/Binoculars
# /wiki/Telescope
# /wiki/Supermassive_black_hole
# /wiki/Sun
# /wiki/Ken_Crawford_(astrophotographer)
# /wiki/Template:POTD/2019-04-29
# /wiki/Template:POTD/2019-04-28
# /wiki/Template:POTD/2019-04-27
# /wiki/Wikipedia:Picture_of_the_day/April_2019
# /wiki/Wikipedia:Featured_pictures
# /wiki/Wikipedia:Local_Embassy
# /wiki/Wikipedia:News
# /wiki/Wikipedia:Village_pump
# /wiki/Talk:Main_Page
# /wiki/Special:WhatLinksHere/Main_Page
# /wiki/Special:RecentChangesLinked/Main_Page

# %% [markdown]
# ## 3.2.1 サイト全体でデータを収集する
# ## Collecting Data Across an Entire Site
#
# 先程はページから他のページに飛ぶだけだったが、今度は情報を表示しながら飛び回る。

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages

    # 自分で追加した終了条件
    if len(pages)>10:
        return

    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print('title is', pageUrl)
        #ここでh1を取得することを試みている。
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0])
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
    except AttributeError:
        #h1がない場合errorになるので、exceptを用意している。
        print('This page is missing something! Continuing.')
    
    #でまた深さ優先探索的な
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
#                 print('-'*20)
#                 print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# title is
# Main Page
# <p><b><a href="/wiki/Pitta" title="Pitta">Pittas</a></b> (Pittidae) are a <a href="/wiki/Family_(biology)" title="Family (biology)">family</a> of <a href="/wiki/Bird" title="Bird">birds</a> found in Asia, Australasia and Africa. There are numerous species in three <a href="/wiki/Genus" title="Genus">genera</a>, <i><a href="/wiki/Pitta_(genus)" title="Pitta (genus)">Pitta</a></i>, <i><a href="/wiki/Erythropitta" title="Erythropitta">Erythropitta</a></i> and <i><a href="/wiki/Hydrornis" title="Hydrornis">Hydrornis</a></i>, all similar in general appearance and habits. They are Old World <a href="/wiki/Tyranni" title="Tyranni">suboscines</a>, closely related to the <a href="/wiki/Broadbill" title="Broadbill">broadbills</a>. Pittas are medium-sized by <a href="/wiki/Passerine" title="Passerine">passerine</a> standards, at 15 to 25 cm (5.9–9.8 in) in length, and stocky, with strong, longish legs and long feet. They have very short <a href="/wiki/Tail" title="Tail">tails</a> and stout, slightly decurved <a href="/wiki/Beak" title="Beak">bills</a>. Many have brightly coloured <a href="/wiki/Plumage" title="Plumage">plumage</a>. Most pitta species are <a href="/wiki/Tropics" title="Tropics">tropical</a>, although a few species can be found in <a href="/wiki/Temperate_climate" title="Temperate climate">temperate</a> climates. They are mostly found in forests, but some live in <a href="/wiki/Shrubland" title="Shrubland">scrub</a> and <a href="/wiki/Mangrove_swamp" title="Mangrove swamp">mangroves</a>. They usually forage alone on wet forest floors in areas with good ground cover. They eat <a href="/wiki/Earthworm" title="Earthworm">earthworms</a>, <a href="/wiki/Snail" title="Snail">snails</a>, <a href="/wiki/Insect" title="Insect">insects</a> and similar invertebrate prey, as well as small vertebrates. The main threat to pittas is habitat loss in the form of rapid <a href="/wiki/Deforestation" title="Deforestation">deforestation</a>; they are also targeted by the <a href="/wiki/Wildlife_trade" title="Wildlife trade">cage-bird trade</a>. (<a href="/wiki/Pitta" title="Pitta"><b>Full article...</b></a>)
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia
# Wikipedia
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia:Protection_policy#semi
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia:Requests_for_page_protection
# Wikipedia:Requests for page protection
# <p>This page is for requesting that a page, file or template be <b> fully protected</b>, <b>create protected</b> (<a href="/wiki/Wikipedia:Protection_policy#Creation_protection" title="Wikipedia:Protection policy">salted</a>), <b>extended confirmed protected</b>, <b>semi-protected</b>, added to <b>pending changes</b>, <b>move-protected</b>, <b>template protected</b> (template-specific), <b>upload protected</b> (file-specific), or <b>unprotected</b>. Please read up on the <a href="/wiki/Wikipedia:Protection_policy" title="Wikipedia:Protection policy">protection policy</a>. Full protection is used to stop edit warring between multiple users or to prevent vandalism to <a href="/wiki/Wikipedia:High-risk_templates" title="Wikipedia:High-risk templates">high-risk templates</a>; semi-protection and pending changes are usually used only to prevent IP and new user vandalism (see the <a href="/wiki/Wikipedia:Rough_guide_to_semi-protection" title="Wikipedia:Rough guide to semi-protection">rough guide to semi-protection</a>); and move protection is used to stop <a href="/wiki/Wikipedia:Moving_a_page" title="Wikipedia:Moving a page">pagemove</a> revert wars. Extended confirmed protection is used where semi-protection has proved insufficient (see the <a href="/wiki/Wikipedia:Rough_guide_to_extended_confirmed_protection" title="Wikipedia:Rough guide to extended confirmed protection">rough guide to extended confirmed protection</a>)
# </p>
# /w/index.php?title=Wikipedia:Requests_for_page_protection&action=edit
# title is /wiki/Wikipedia:Requests_for_permissions
# Wikipedia:Requests for permissions
# <p><span class="sysop-show" id="coordinates"><a href="/wiki/Wikipedia:Requests_for_permissions/Administrator_instructions" title="Wikipedia:Requests for permissions/Administrator instructions">Administrator instructions</a></span>
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia:Protection_policy#template
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia:Lists_of_protected_pages
# Wikipedia:Lists of protected pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia:Protection_policy
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# title is /wiki/Wikipedia:Perennial_proposals
# Wikipedia:Perennial proposals
# <p>This is a list of things that have frequently been proposed on Wikipedia, and have been <a class="mw-redirect" href="/wiki/Wikipedia:Rejected_proposals" title="Wikipedia:Rejected proposals">rejected by the community</a> several times in the past. It should be noted that merely listing something on this page does not mean it will never happen, but that it has been discussed before and never met consensus.  <a class="mw-redirect" href="/wiki/Wikipedia:Consensus_can_change" title="Wikipedia:Consensus can change">Consensus can change</a>, and some proposals that remained on this page for a long time have finally been proposed in a way that reached consensus, but you should address rebuttals raised in the past if you make a proposal along these lines.  If you feel you would still like to do one of these proposals, then raise it at the <a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Village pump">Wikipedia:Village pump</a>.
# </p>
# /w/index.php?title=Wikipedia:Perennial_proposals&action=edit
# title is /wiki/Wikipedia:Reliable_sources/Perennial_sources
# Wikipedia:Reliable sources/Perennial sources
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Wikipedia:Reliable_sources/Perennial_sources&action=edit
# title is /wiki/Wikipedia:Reliable_sources
# Wikipedia:Reliable sources
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.

# %% [markdown]
# ## 3.3 インターネットをクローリング
# ## Crawling across the Internet
#
# 単一ドメインだけでなく外部のサイトもクローリングする。
# 自分の目的とは沿わないので飛ばす

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl):
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bs = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        internalLinks = getInternalLinks(bs, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,
                                    len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('http://oreilly.com')
# Out:
# Random external link is: http://twitter.com/oreillymedia
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a23b136d3234> in <module>()
#      52     followExternalOnly(externalLink)
#      53
# ---> 54 followExternalOnly('http://oreilly.com')
#
# <ipython-input-6-a23b136d3234> in followExternalOnly(startingSite)
#      50     externalLink = getRandomExternalLink(startingSite)
#      51     print('Random external link is: {}'.format(externalLink))
# ---> 52     followExternalOnly(externalLink)
#      53
#      54 followExternalOnly('http://oreilly.com')
#
# <ipython-input-6-a23b136d3234> in followExternalOnly(startingSite)
#      48
#      49 def followExternalOnly(startingSite):
# ---> 50     externalLink = getRandomExternalLink(startingSite)
#      51     print('Random external link is: {}'.format(externalLink))
#      52     followExternalOnly(externalLink)
#
# <ipython-input-6-a23b136d3234> in getRandomExternalLink(startingPage)
#      36 def getRandomExternalLink(startingPage):
#      37     html = urlopen(startingPage)
# ---> 38     bs = BeautifulSoup(html, 'html.parser')
#      39     externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
#      40     if len(externalLinks) == 0:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     213         parser.soup = self.soup
#     214         try:
# --> 215             parser.feed(markup)
#     216         except HTMLParseError as e:
#     217             warnings.warn(RuntimeWarning(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     301     def parse_starttag(self, i):
#     302         self.__starttag_text = None
# --> 303         endpos = self.check_for_whole_start_tag(i)
#     304         if endpos < 0:
#     305             return endpos
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/html/parser.py in check_for_whole_start_tag(self, i)
#     355         if m:
#     356             j = m.end()
# --> 357             next = rawdata[j:j+1]
#     358             if next == ">":
#     359                 return j + 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('http://oreilly.com')
getAllExternalLinks('http://oreilly.com')
# Out:
# https://www.oreilly.com
# http://www.oreilly.com/ideas
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170601+nav
# http://www.oreilly.com/conferences/
# http://shop.oreilly.com/
# http://members.oreilly.com
# https://www.oreilly.com/topics
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170505+homepage+get+started+now
# https://www.safaribooksonline.com/accounts/login/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170203+homepage+sign+in
# https://www.safaribooksonline.com/live-training/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170201+homepage+take+a+live+online+course
# https://www.safaribooksonline.com/learning-paths/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170201+homepage+follow+a+path
# https://www.safaribooksonline.com/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170505+homepage+unlimited+access
# http://www.oreilly.com/live-training/?view=grid
# https://www.safaribooksonline.com/your-experience/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170201+homepage+safari+platform
# https://cdn.oreillystatic.com/pdf/oreilly_high_performance_organizations_whitepaper.pdf
# https://www.oreilly.com/ideas/8-data-trends-on-our-radar-for-2017?utm_medium=referral&utm_source=oreilly.com&utm_campaign=lgen&utm_content=link+2017+trends
# https://www.oreilly.com/ideas?utm_medium=referral&utm_source=oreilly.com&utm_campaign=lgen&utm_content=link+read+latest+articles
# http://www.oreilly.com/about/
# http://www.oreilly.com/work-with-us.html
# http://www.oreilly.com/careers/
# http://shop.oreilly.com/category/customer-service.do
# http://www.oreilly.com/about/contact.html
# http://twitter.com/oreillymedia
# http://fb.co/OReilly
# https://www.linkedin.com/company/oreilly-media
# https://www.youtube.com/user/OreillyMedia
# http://www.oreilly.com/emails/newsletters/
# http://www.oreilly.com/terms/
# http://www.oreilly.com/privacy.html
# http://www.oreilly.com/about/editorial_independence.html
# https://www.safaribooksonline.com/home/?utm_medium=content&utm_source=oreilly.com&utm_campaign=lgen&utm_content=20170601+nav
# http://www.oreilly.com/emails/newsletters/?display=preview#ai
# https://www.oreilly.com/privacy.html
# http://www.oreilly.com/ai/building-bots-with-natural-language-processing.csp?utm_source=oreilly&utm_medium=newsite&utm_campaign=ai-topic-cta
# https://www.flickr.com/photos/ebmorse/7536436622/in/dateposted/
# http://oreilly.com/about/
# http://oreilly.com/work-with-us.html
# http://oreilly.com/careers/
# https://plus.google.com/+oreillymedia
# http://oreilly.com/terms/
# http://oreilly.com/privacy.html
# https://www.safaribooksonline.com/home/?utm_source=newsite&utm_medium=content&utm_campaign=lgen&utm_content=business-topic-cta
# https://www.flickr.com/photos/pagedooley/4253159181/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-846c414ed600> in <module>()
#      19
#      20 allIntLinks.add('http://oreilly.com')
# ---> 21 getAllExternalLinks('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#      16         if link not in allIntLinks:
#      17             allIntLinks.add(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20 allIntLinks.add('http://oreilly.com')
#
# <ipython-input-8-846c414ed600> in getAllExternalLinks(siteUrl)
#       3 allIntLinks = set()
#       4 def getAllExternalLinks(siteUrl):
# ----> 5     html = urlopen(siteUrl)
#       6     domain = '{}://{}'.format(urlparse(siteUrl).scheme, urlparse(siteUrl).netloc)
#       7     bs = BeautifulSoup(html, 'html.parser')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     562             http_err = 0
#     563         args = (dict, proto, meth_name) + args
# --> 564         result = self._call_chain(*args)
#     565         if result:
#     566             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     754         fp.close()
#     755
# --> 756         return self.parent.open(new, timeout=req.timeout)
#     757
#     758     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
